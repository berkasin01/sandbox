# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

encoders = {}
scalers  = {}

or_cols = ['Title', 'Embarked', 'Sex', 'Ticket', 'Cabin_Title']
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])
    encoders[col] = enc                      

scale_cols = ["Fare", "SibSp", "Parch", "Age", "Pclass"]
sc = StandardScaler()
age_df[scale_cols] = sc.fit_transform(age_df[scale_cols])
scalers["standard"] = (sc, scale_cols)

# %%
def untransform(df):
    out = df.copy()
    s, cols = scalers["standard"]
    out[cols] = s.inverse_transform(out[cols])
    for col, enc in encoders.items():
        out[col] = enc.inverse_transform(out[[col]]).ravel()
    return out

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.4183568291379631, inertia:4628.916075983701
# n_clusters:3, sil_score:0.3339064558156853, inertia:3580.379372824385
# n_clusters:4, sil_score:0.3530197192607629, inertia:3046.7428394593016
# n_clusters:5, sil_score:0.3190686976335384, inertia:2728.1124981595676
# n_clusters:6, sil_score:0.3445375405129062, inertia:2448.446057689245
# n_clusters:7, sil_score:0.3383664469366949, inertia:2190.082660628415
# n_clusters:8, sil_score:0.36386300089360596, inertia:2111.883413267182
# n_clusters:9, sil_score:0.369510255531891, inertia:1882.602691131658
# n_clusters:10, sil_score:0.43376973467816893, inertia:1625.1649447999428
# n_clusters:11, sil_score:0.4035394508428332, inertia:1707.062714746426
# n_clusters:12, sil_score:0.44064305778529017, inertia:1407.1392161574645
# n_clusters:13, sil_score:0.47170690909759794, inertia:1337.0976128994168
# n_clusters:14, sil_score:0.46476362766436546, inertia:1295.5923349277007
# n_clusters:15, sil_score:0.4549059463663698, inertia:1233.9784338627526
# n_clusters:16, sil_score:0.5070550003587759, inertia:1113.1328503161553
# n_clusters:17, sil_score:0.496625323130917, inertia:1064.0552177855775
# n_clusters:18, sil_score:0.5045631568680997, inertia:1029.6178060496827
# n_clusters:19, sil_score:0.5219752976076811, inertia:950.6937237626299
# n_clusters:20, sil_score:0.534763136158455, inertia:949.5241541801338
# n_clusters:21, sil_score:0.5427095294613877, inertia:897.7395088529828
# n_clusters:22, sil_score:0.5628067355063838, inertia:833.4139696424882
# n_clusters:23, sil_score:0.5498885707043664, inertia:843.8822553995126
# n_clusters:24, sil_score:0.5660477013678747, inertia:800.3294391815195
# n_clusters:25, sil_score:0.5546883640994702, inertia:807.085625135804
# n_clusters:26, sil_score:0.5671891569083392, inertia:770.7859478059293
# n_clusters:27, sil_score:0.5515072675368373, inertia:774.3429223695143
# n_clusters:28, sil_score:0.5667963614501077, inertia:698.7026159261133
# n_clusters:29, sil_score:0.596745519264897, inertia:673.8136420084556
# n_clusters:30, sil_score:0.5859568695660407, inertia:667.0659835533218
# n_clusters:31, sil_score:0.6120187664585, inertia:646.7681551204977
# n_clusters:32, sil_score:0.6061879207981392, inertia:615.2343299824895
# n_clusters:33, sil_score:0.6215006594415585, inertia:591.2742952644712
# n_clusters:34, sil_score:0.6343843986795868, inertia:567.6999623054975
# n_clusters:35, sil_score:0.6263650245867473, inertia:589.7622259707697
# n_clusters:36, sil_score:0.6480055176511388, inertia:556.4958426484822
# n_clusters:37, sil_score:0.6347044649088779, inertia:527.5666713226725
# n_clusters:38, sil_score:0.6520558791779668, inertia:510.40257724655936
# n_clusters:39, sil_score:0.6493540235142979, inertia:510.33427310949

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#                  mean       std       var  count
# cluster
# 0        1.090056e-16  1.000478  1.000957   1046
#              mean       std       var  count
# cluster
# 0       -0.942693  1.061497  1.126776    153
# 1        0.161514  0.895597  0.802094    893
#              mean       std       var  count
# cluster
# 0       -0.089314  0.766661  0.587770    601
# 1        0.623112  0.939501  0.882662    310
# 2       -1.033237  1.062647  1.129218    135
#              mean       std       var  count
# cluster
# 0       -0.297566  0.784643  0.615664    467
# 1        0.507409  0.922138  0.850338    442
# 2       -1.384134  0.583685  0.340688     42
# 3       -0.286081  1.161180  1.348338     95
#              mean       std       var  count
# cluster
# 0        0.573789  0.948738  0.900105    139
# 1       -0.349181  0.881097  0.776333    111
# 2       -1.005032  1.051125  1.104863    108
# 3       -0.118711  0.758238  0.574924    470
# 4        0.565780  0.968954  0.938872    218
#              mean       std       var  count
# cluster
# 0        0.712762  0.958928  0.919542    264
# 1        0.241621  0.906658  0.822029     58
# 2       -1.463547  0.590975  0.349251     97
# 3       -0.039522  0.742779  0.551720    510
# 4       -0.279862  0.830808  0.690243    110
# 5       -1.325463  0.348136  0.121198      7
#              mean       std       var  count
# cluster
# 0       -0.617202  1.053119  1.109060    125
# 1       -0.073346  0.710660  0.505037    282
# 2       -1.450328  0.521718  0.272190     38
# 3        0.491267  0.944405  0.891901    290
# 4       -0.527376  0.708329  0.501730    157
# 5        0.899936  0.644234  0.415037     13
# 6        0.578566  0.906458  0.821665    141
#              mean       std       var  count
# cluster
# 0        0.587925  0.952698  0.907634    131
# 1       -0.757911  0.781942  0.611433    126
# 2       -0.020364  0.758995  0.576074    376
# 3       -1.289765  0.636216  0.404771     50
# 4        0.620592  0.920112  0.846607    216
# 5       -0.492057  0.790479  0.624857     75
# 6       -0.076795  1.092577  1.193724     71
# 7       -1.067645       NaN       NaN      1
#              mean       std       var  count
# cluster
# 0       -1.297763  0.608801  0.370639     46
# 1       -0.095180  0.685321  0.469665    252
# 2        0.341376  0.959146  0.919962    227
# 3        0.747707  0.936165  0.876405     49
# 4       -0.878016  0.791722  0.626823    152
# 5        0.518166  0.874201  0.764228    130
# 6        0.341890  0.998002  0.996009    106
# 7       -0.213336  0.803010  0.644825     65
# 8        0.698723  0.818518  0.669971     19
#              mean       std       var  count
# cluster
# 0       -0.778562  0.686508  0.471293     85
# 1        0.673516  0.941853  0.887088     95
# 2        0.140809  0.835079  0.697357    144
# 3       -1.411149  0.569993  0.324893     39
# 4       -0.287824  0.831048  0.690641     81
# 5       -0.101767  0.683494  0.467164    253
# 6       -1.065071  0.901259  0.812268     72
# 7        0.570989  0.897727  0.805915    112
# 8        0.622741  0.923387  0.852644    129
# 9        0.511492  0.748586  0.560381     36
#              mean       std       var  count
# cluster
# 0        0.623887  0.927375  0.860025    130
# 1       -0.081908  0.712372  0.507474    266
# 2        0.673516  0.941853  0.887088     95
# 3       -1.327116  0.622322  0.387284     42
# 4       -1.056263  0.965631  0.932444     93
# 5        0.925489  0.626301  0.392253     14
# 6       -0.453467  0.757661  0.574050     73
# 7       -1.067645       NaN       NaN      1
# 8        0.546342  0.889199  0.790675    121
# 9       -0.403212  0.580155  0.336579     90
# 10       0.182356  0.856995  0.734441    121
#              mean       std       var  count
# cluster
# 0        0.301115  0.755100  0.570176     73
# 1       -0.108831  0.670175  0.449135    249
# 2        0.543614  0.904709  0.818498    141
# 3       -1.067645       NaN       NaN      1
# 4        1.062984  0.970440  0.941753     41
# 5       -1.327116  0.622322  0.387284     42
# 6       -0.604293  0.529313  0.280172     77
# 7        0.353126  0.917096  0.841066    238
# 8        0.360794  0.794075  0.630556     38
# 9       -1.489376  0.578280  0.334407     77
# 10      -0.116940  0.781083  0.610090     56
# 11       0.899936  0.644234  0.415037     13
#              mean       std       var  count
# cluster
# 0       -0.217025  0.844860  0.713789     55
# 1       -0.099561  0.673693  0.453862    235
# 2       -1.450328  0.521718  0.272190     38
# 3        0.777574  0.490338  0.240431     12
# 4        0.638473  0.928464  0.862045    126
# 5        0.938928  0.914574  0.836445    114
# 6        0.067945  0.918052  0.842820     25
# 7        0.144940  0.688351  0.473827     65
# 8       -0.295292  0.622189  0.387119     63
# 9       -0.278577  1.071064  1.147179     68
# 10       0.227972  0.853720  0.728839    136
# 11      -0.640565  0.618207  0.382179     72
# 12      -1.752091  0.283925  0.080614     37
#              mean       std       var  count
# cluster
# 0        0.678378  0.945704  0.894356     94
# 1       -0.564404  0.490292  0.240386     74
# 2       -1.420188  0.574805  0.330400     38
# 3        0.658205  0.276386  0.076389     11
# 4        0.271202  0.707637  0.500750     85
# 5       -0.088534  0.700083  0.490116    265
# 6        0.988597  0.917546  0.841891     81
# 7        0.235127  0.908177  0.824785    108
# 8       -1.329815  0.666985  0.444869     43
# 9        0.093747  1.154842  1.333659     41
# 10      -1.067645       NaN       NaN      1
# 11       0.160091  0.754104  0.568673     32
# 12       0.140809  0.835079  0.697357    144
# 13      -1.769957  0.272517  0.074265     29
#              mean       std       var  count
# cluster
# 0       -0.087027  0.688032  0.473388    263
# 1        0.555743  0.901704  0.813071     80
# 2       -0.232698  1.124375  1.264220     32
# 3       -1.420188  0.574805  0.330400     38
# 4        0.163674  0.637343  0.406206     46
# 5       -1.067645       NaN       NaN      1
# 6       -1.248639  0.766714  0.587850     24
# 7       -0.362349  0.537811  0.289241     87
# 8       -1.545068  0.502378  0.252384     56
# 9        0.678378  0.945704  0.894356     94
# 10       0.176946  0.855536  0.731941    122
# 11      -0.107963  0.744305  0.553990     66
# 12       0.745430  0.945833  0.894600     79
# 13       0.759718  0.943638  0.890452     46
# 14       0.777574  0.490338  0.240431     12
#              mean       std       var  count
# cluster
# 0       -0.403212  0.580155  0.336579     90
# 1       -1.049820  0.981256  0.962864     25
# 2        0.678378  0.945704  0.894356     94
# 3       -1.420188  0.574805  0.330400     38
# 4        0.170706  0.628562  0.395091     47
# 5        0.474768  1.095766  1.200702     43
# 6       -0.108831  0.670175  0.449135    249
# 7        0.166692  0.850204  0.722846    115
# 8        0.899936  0.644234  0.415037     13
# 9       -0.185763  0.764180  0.583970     61
# 10       0.896154  0.992022  0.984108     72
# 11      -1.761327  0.281454  0.079216     25
# 12      -1.067645       NaN       NaN      1
# 13      -0.848608  0.966536  0.934191     52
# 14       0.523815  0.852672  0.727049     69
# 15       0.392690  0.809537  0.655350     52
#              mean       std       var  count
# cluster
# 0       -0.396788  0.584804  0.341995     88
# 1        0.543842  0.901228  0.812211     81
# 2       -1.476188  0.483263  0.233543     35
# 3        0.642172  0.927508  0.860270     98
# 4        0.837681  0.886324  0.785570     69
# 5       -0.093440  0.687251  0.472313    243
# 6       -1.697218  0.366846  0.134576     37
# 7       -0.398309  0.621732  0.386550     21
# 8       -0.346217  1.133275  1.284312     39
# 9        0.190932  0.859676  0.739043    110
# 10      -0.182634  0.756283  0.571964     72
# 11       0.144907  0.552561  0.305324     32
# 12       0.776417  0.871108  0.758830     15
# 13      -0.213422  0.892417  0.796408     31
# 14       0.806496  0.147246  0.021682      2
# 15      -0.995776  1.162677  1.351817     26
# 16       0.764405  0.933878  0.872127     47
#              mean       std       var  count
# cluster
# 0       -0.088693  0.688770  0.474405    237
# 1       -0.389715  0.571210  0.326280     30
# 2        1.046961  0.854416  0.730027     28
# 3        0.678378  0.945704  0.894356     94
# 4        0.764405  0.933878  0.872127     47
# 5        0.658205  0.276386  0.076389     11
# 6       -0.457486  0.442077  0.195432     62
# 7        0.091733  0.654299  0.428107     37
# 8        0.604415  0.924982  0.855591     62
# 9       -1.499546  0.475322  0.225931     36
# 10      -0.043469  0.779599  0.607775     51
# 11       0.159061  0.842814  0.710335    139
# 12      -0.480381  1.219066  1.486122     42
# 13       0.218728  0.688430  0.473936     31
# 14      -1.628484  0.453675  0.205821     45
# 15       0.458957  0.900740  0.811333     73
# 16      -1.067645       NaN       NaN      1
# 17      -1.385485  0.448441  0.201100     20
#              mean       std       var  count
# cluster
# 0       -0.099561  0.673693  0.453862    235
# 1        0.406970  1.195573  1.429395     43
# 2       -0.267978  1.017226  1.034749     41
# 3       -0.101653  0.743549  0.552865     60
# 4        1.173652  0.891795  0.795298     19
# 5        0.190932  0.859676  0.739043    110
# 6       -1.469760  0.502901  0.252909     29
# 7       -1.695706  0.407056  0.165695     45
# 8       -0.569047  0.494984  0.245009     71
# 9       -0.110445  0.788316  0.621443     50
# 10       0.837681  0.886324  0.785570     69
# 11       0.574419  0.899863  0.809754     99
# 12       0.813437  1.086332  1.180116     10
# 13       0.421708  0.764864  0.585017     46
# 14       0.693700  0.107773  0.011615      8
# 15      -0.805860  0.769321  0.591855     35
# 16       0.055151  0.681489  0.464427     37
# 17      -0.385088  0.888915  0.790170      9
# 18       0.880536  1.016022  1.032300     30

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0     -0.099796
# 1      0.747707
# 2     -0.099796
# 3      0.707335
# 4     -0.099796
#          ...
# 413   -0.099796
# 414    0.747707
# 415   -0.099796
# 416   -0.099796
# 417   -1.377422
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str.split().str[0]

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str[0]

# %%
cabin_df.Cabin
# Out:
# 1      C
# 3      C
# 6      E
# 10     G
# 11     C
#       ..
# 404    D
# 405    D
# 407    C
# 411    C
# 414    C
# Name: Cabin, Length: 295, dtype: object

# %%
cabin_df["Cabin"].value_counts()
# Out:
# Cabin
# C    94
# B    65
# D    46
# E    41
# A    22
# F    21
# G     5
# T     1
# Name: count, dtype: int64

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived    Pclass  \
# 1             2       1.0 -1.546098
# 3             4       1.0 -1.546098
# 6             7       0.0 -1.546098
# 10           11       1.0  0.841916
# 11           12       1.0 -1.546098
#
#                                                  Name  Sex       Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  0.563552
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  0.355314
# 6                             McCarthy, Mr. Timothy J  1.0  1.674153
# 10                    Sandstrom, Miss. Marguerite Rut  0.0 -1.796478
# 11                           Bonnell, Miss. Elizabeth  0.0  1.951804
#
#        SibSp     Parch  Ticket      Fare Cabin  Embarked  train_col  Title  \
# 1   0.481288 -0.445000   816.0  0.734744     C       0.0          1    3.0
# 3   0.481288 -0.445000    65.0  0.383183     C       2.0          1    3.0
# 6  -0.479087 -0.445000   109.0  0.359257     E       2.0          1    2.0
# 10  0.481288  0.710763   839.0 -0.320583     G       2.0          1    1.0
# 11 -0.479087 -0.445000    50.0 -0.130140     C       2.0          1    1.0
#
#     Cabin_Title  cluster
# 1           2.0       10
# 3           2.0        1
# 6           4.0        1
# 10          6.0        5
# 11          2.0        0

# %%
cabin_df = age_df[~cabin_con].copy()   # .copy() — you're currently on a slice

X = cabin_df.drop(["Cabin", "Cabin_Title", "Name", "Ticket",
                   "PassengerId", "Survived", "train_col"], axis=1)
y = cabin_df["Cabin"]

from sklearn.preprocessing import StandardScaler
X[["Age", "Pclass"]] = StandardScaler().fit_transform(X[["Age", "Pclass"]])
