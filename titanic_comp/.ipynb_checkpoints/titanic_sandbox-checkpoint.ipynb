# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df.dropna(subset=["Fare","Embarked"],inplace=True)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        417
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1013
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Age", "Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Ticket","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.6488795426738395, inertia:22654673.66873739
# n_clusters:3, sil_score:0.60670909726473, inertia:9939353.085560543
# n_clusters:4, sil_score:0.58616437211568, inertia:5567129.228880978
# n_clusters:5, sil_score:0.5813960827109835, inertia:3492730.5861560255
# n_clusters:6, sil_score:0.5507303017432515, inertia:2619993.6711299834
# n_clusters:7, sil_score:0.5498972934557885, inertia:1879493.0869807927
# n_clusters:8, sil_score:0.5486068818271486, inertia:1471525.4610936602
# n_clusters:9, sil_score:0.5456753793876749, inertia:1115705.3967789023
# n_clusters:10, sil_score:0.5454072691411276, inertia:922452.0694803855
# n_clusters:11, sil_score:0.5367476743870623, inertia:788792.176959026
# n_clusters:12, sil_score:0.5413889560204115, inertia:631861.1117681917
# n_clusters:13, sil_score:0.5267690527904555, inertia:583028.1151153797
# n_clusters:14, sil_score:0.5365270025647597, inertia:475167.1949870916
# n_clusters:15, sil_score:0.5275964892762548, inertia:437301.7654190846
# n_clusters:16, sil_score:0.5365071970433931, inertia:362946.71402972064
# n_clusters:17, sil_score:0.5251125917643837, inertia:327832.8142353391
# n_clusters:18, sil_score:0.5254716905929789, inertia:291740.2738785231
# n_clusters:19, sil_score:0.5255756647732122, inertia:269490.3026432952
# n_clusters:20, sil_score:0.5156515749260742, inertia:239908.01641170395
# n_clusters:21, sil_score:0.5205946845577063, inertia:225666.12638093866
# n_clusters:22, sil_score:0.5132194079501415, inertia:210278.54109677084
# n_clusters:23, sil_score:0.5243881126100265, inertia:174228.51564710727
# n_clusters:24, sil_score:0.5275717716976851, inertia:161441.2670069148
# n_clusters:25, sil_score:0.5171654878389615, inertia:158553.95904259715
# n_clusters:26, sil_score:0.5213832760836182, inertia:135772.30209897098
# n_clusters:27, sil_score:0.5252642073036503, inertia:126863.6689809445
# n_clusters:28, sil_score:0.5145144161525421, inertia:122066.69927974397
# n_clusters:29, sil_score:0.5159675157255813, inertia:115642.70699261253
# n_clusters:30, sil_score:0.5159094497572537, inertia:105328.95970460211
# n_clusters:31, sil_score:0.512667439179515, inertia:98753.85136997371
# n_clusters:32, sil_score:0.5123013178705835, inertia:98960.1925379731
# n_clusters:33, sil_score:0.5152319776116774, inertia:87838.93550063444
# n_clusters:34, sil_score:0.5094143672772496, inertia:84180.02489062422
# n_clusters:35, sil_score:0.5126187769480295, inertia:77919.18906013569
# n_clusters:36, sil_score:0.5090878152032956, inertia:73836.4900065738
# n_clusters:37, sil_score:0.5047900555573565, inertia:70518.88458343103
# n_clusters:38, sil_score:0.503863576310577, inertia:69378.92374211467
# n_clusters:39, sil_score:0.509397757947283, inertia:63793.409728393584

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(3,7,1):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        32.663945  14.976733  224.302542    365
# 1        25.889747  12.355917  152.668688    316
# 2        30.363729  14.640714  214.350511    362
#               mean        std         var  count
# cluster
# 0        27.240448  13.173742  173.547490    201
# 1        24.833659  13.215605  174.652214    246
# 2        34.946221  14.352229  205.986475    299
# 3        30.511246  14.322706  205.139899    297
#               mean        std         var  count
# cluster
# 0        25.533125  12.328558  151.993347    176
# 1        35.646971  14.375699  206.660711    241
# 2        30.674686  14.566600  212.185845    271
# 3        26.325000  13.728301  188.466253    210
# 4        28.754000  13.903318  193.302251    145
#               mean        std         var  count
# cluster
# 0        24.975057  13.167867  173.392714    174
# 1        29.015504  14.808197  219.282709    129
# 2        35.951689  14.619775  213.737822    219
# 3        31.110172  14.525252  210.982934    233
# 4        28.134479  13.968156  195.109392    163
# 5        26.388000  11.041320  121.910742    125

# %%
k_best = KMeans(n_clusters=5)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      27.869177
# 1      30.760290
# 2      30.760290
# 3      35.713950
# 4      27.869177
#          ...
# 413    27.869177
# 414    30.760290
# 415    30.760290
# 416    27.869177
# 417    26.739950
# Name: Age, Length: 1306, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        417
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1013
# Embarked          0
# train_col         0
# Title             0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1306, 15)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 185, dtype: int64
