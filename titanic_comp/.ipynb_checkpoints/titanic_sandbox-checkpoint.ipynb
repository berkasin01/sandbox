# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

encoders = {}
scalers  = {}

or_cols = ['Title', 'Embarked', 'Sex', 'Ticket', 'Cabin_Title']
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])
    encoders[col] = enc                      

scale_cols = ["Fare", "SibSp", "Parch", "Age", "Pclass"]
sc = StandardScaler()
age_df[scale_cols] = sc.fit_transform(age_df[scale_cols])
scalers["standard"] = (sc, scale_cols)

# %%
def untransform(df):
    out = df.copy()
    s, cols = scalers["standard"]
    out[cols] = s.inverse_transform(out[cols])
    for col, enc in encoders.items():
        out[col] = enc.inverse_transform(out[[col]]).ravel()
    return out

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.4183568291379631, inertia:4628.916075983701
# n_clusters:3, sil_score:0.31993884877796847, inertia:3836.5901375962494
# n_clusters:4, sil_score:0.28189138543230796, inertia:3220.820022443858
# n_clusters:5, sil_score:0.3163232154728825, inertia:2761.6116046528387
# n_clusters:6, sil_score:0.3535969272887864, inertia:2327.998404271621
# n_clusters:7, sil_score:0.35716412758507954, inertia:2365.279291152263
# n_clusters:8, sil_score:0.36870917851975604, inertia:2099.7607513790445
# n_clusters:9, sil_score:0.40036263661152494, inertia:1759.869004841527
# n_clusters:10, sil_score:0.41949284569670203, inertia:1611.5073413124126
# n_clusters:11, sil_score:0.4321279307835873, inertia:1476.6185243397445
# n_clusters:12, sil_score:0.4148402394874402, inertia:1480.2439983038055
# n_clusters:13, sil_score:0.447847172489166, inertia:1418.082163800776
# n_clusters:14, sil_score:0.47855948906619605, inertia:1256.1182506247176
# n_clusters:15, sil_score:0.4477630678390801, inertia:1253.8117881187973
# n_clusters:16, sil_score:0.47779740836122736, inertia:1235.79485344338
# n_clusters:17, sil_score:0.49632137278155536, inertia:1136.1003728371581
# n_clusters:18, sil_score:0.4934131685749054, inertia:1063.0739518130947
# n_clusters:19, sil_score:0.4652983104768979, inertia:1062.9364638209347
# n_clusters:20, sil_score:0.5048484114316949, inertia:965.7609888080527
# n_clusters:21, sil_score:0.5431794645774969, inertia:944.4298144110949
# n_clusters:22, sil_score:0.554062791581772, inertia:857.7780662611663
# n_clusters:23, sil_score:0.5438438408945047, inertia:824.0140674399977
# n_clusters:24, sil_score:0.5372808909649167, inertia:857.0842713107921
# n_clusters:25, sil_score:0.5676944776155757, inertia:798.4118604751019
# n_clusters:26, sil_score:0.5554077252567166, inertia:810.3206965543982
# n_clusters:27, sil_score:0.6047135859327419, inertia:716.5539276609155
# n_clusters:28, sil_score:0.5960134622222213, inertia:674.5890164780199
# n_clusters:29, sil_score:0.5894622912795837, inertia:666.627081273792
# n_clusters:30, sil_score:0.6190061958872922, inertia:645.2881349573105
# n_clusters:31, sil_score:0.5998821055015502, inertia:627.1693893551568
# n_clusters:32, sil_score:0.6277676643906255, inertia:625.4840736705448
# n_clusters:33, sil_score:0.5958230934642484, inertia:636.1897472336548
# n_clusters:34, sil_score:0.6367619613479502, inertia:583.1272800605734
# n_clusters:35, sil_score:0.6460364915250837, inertia:539.246803122404
# n_clusters:36, sil_score:0.6196958012581044, inertia:540.5889106951989
# n_clusters:37, sil_score:0.6594309702173276, inertia:529.4182298814901
# n_clusters:38, sil_score:0.6520447836822847, inertia:511.05811101080695
# n_clusters:39, sil_score:0.6704185369137954, inertia:494.8051314329087

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#                  mean       std       var  count
# cluster
# 0        1.090056e-16  1.000478  1.000957   1046
#              mean       std       var  count
# cluster
# 0       -0.300139  0.871600  0.759686    678
# 1        0.552974  0.987785  0.975719    368
#              mean       std       var  count
# cluster
# 0       -0.866383  1.088215  1.184211    160
# 1       -0.085381  0.767690  0.589348    594
# 2        0.648416  0.947104  0.897005    292
#              mean       std       var  count
# cluster
# 0       -0.261417  0.761158  0.579362    442
# 1        0.480842  0.988342  0.976820    154
# 2        0.293763  1.024460  1.049518    373
# 3       -0.884116  1.102857  1.216294     77
#              mean       std       var  count
# cluster
# 0        0.649398  0.916864  0.840640    321
# 1       -0.091747  0.729306  0.531887    539
# 2        0.511492  0.777369  0.604302     40
# 3       -1.151409  0.884529  0.782392    108
# 4       -1.450328  0.521718  0.272190     38
#              mean       std       var  count
# cluster
# 0        0.517039  0.924003  0.853782    438
# 1       -1.099695  0.906223  0.821241     98
# 2       -0.141707  0.661722  0.437876    318
# 3       -1.450328  0.521718  0.272190     38
# 4        0.556780  0.820539  0.673284     41
# 5       -0.365890  0.777292  0.604183    113
#              mean       std       var  count
# cluster
# 0       -0.068289  0.714702  0.510798    448
# 1        0.675239  0.920534  0.847383    188
# 2       -1.450328  0.521718  0.272190     38
# 3        0.556047  0.786299  0.618267     37
# 4        0.608512  0.918971  0.844507    132
# 5       -1.123501  0.896181  0.803141     96
# 6       -0.320376  0.867330  0.752262    107
#              mean       std       var  count
# cluster
# 0       -0.277541  0.828602  0.686582     81
# 1       -0.088268  0.677160  0.458545    274
# 2       -1.450328  0.521718  0.272190     38
# 3        0.478739  0.935680  0.875498    302
# 4       -0.254866  1.132600  1.282783     82
# 5       -0.762067  0.776871  0.603529    128
# 6        0.417181  0.978466  0.957397     92
# 7        0.760457  0.947441  0.897644     49
#              mean       std       var  count
# cluster
# 0       -0.535601  0.697032  0.485854     99
# 1        0.636731  0.918860  0.844303    129
# 2       -1.136689  0.796051  0.633698     79
# 3       -0.340453  0.849614  0.721845     88
# 4       -1.420188  0.574805  0.330400     38
# 5        0.511492  0.777369  0.604302     40
# 6       -0.088876  0.678328  0.460129    273
# 7       -1.067645       NaN       NaN      1
# 8        0.499943  0.932321  0.869223    299
#              mean       std       var  count
# cluster
# 0       -0.071610  0.704493  0.496311    289
# 1        0.899936  0.644234  0.415037     13
# 2        0.673516  0.941853  0.887088     95
# 3        0.384236  0.921903  0.849906    180
# 4       -1.329099  0.618973  0.383128     45
# 5       -1.067645       NaN       NaN      1
# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0     -0.075069
# 1      0.731914
# 2     -0.500256
# 3      0.675970
# 4     -0.075069
#          ...
# 413   -0.075069
# 414    0.731914
# 415   -0.075069
# 416   -0.075069
# 417   -0.500256
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived    Pclass  \
# 1             2       1.0 -1.546098
# 3             4       1.0 -1.546098
# 6             7       0.0 -1.546098
# 10           11       1.0  0.841916
# 11           12       1.0 -1.546098
#
#                                                  Name  Sex       Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  0.563552
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  0.355314
# 6                             McCarthy, Mr. Timothy J  1.0  1.674153
# 10                    Sandstrom, Miss. Marguerite Rut  0.0 -1.796478
# 11                           Bonnell, Miss. Elizabeth  0.0  1.951804
#
#        SibSp     Parch  Ticket      Fare Cabin  Embarked  train_col  Title  \
# 1   0.481288 -0.445000   816.0  0.734744     C       0.0          1    3.0
# 3   0.481288 -0.445000    65.0  0.383183     C       2.0          1    3.0
# 6  -0.479087 -0.445000   109.0  0.359257     E       2.0          1    2.0
# 10  0.481288  0.710763   839.0 -0.320583     G       2.0          1    1.0
# 11 -0.479087 -0.445000    50.0 -0.130140     C       2.0          1    1.0
#
#     Cabin_Title  cluster
# 1           2.0        2
# 3           2.0        6
# 6           4.0        4
# 10          6.0        8
# 11          2.0        4

# %%
cabin_df = age_df[~cabin_con].copy()
cabin_df["Cabin"] = cabin_df["Cabin"].str[0]       

feature_cols = ["Pclass", "Sex", "Age", "SibSp", "Parch",
                "Fare", "Embarked", "Title", "Ticket", "cluster"]

X_train = cabin_df[feature_cols]      
y_train = cabin_df["Cabin"]

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived    Pclass  \
# 1             2       1.0 -1.546098
# 3             4       1.0 -1.546098
# 6             7       0.0 -1.546098
# 10           11       1.0  0.841916
# 11           12       1.0 -1.546098
#
#                                                  Name  Sex       Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  0.563552
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  0.355314
# 6                             McCarthy, Mr. Timothy J  1.0  1.674153
# 10                    Sandstrom, Miss. Marguerite Rut  0.0 -1.796478
# 11                           Bonnell, Miss. Elizabeth  0.0  1.951804
#
#        SibSp     Parch  Ticket      Fare Cabin  Embarked  train_col  Title  \
# 1   0.481288 -0.445000   816.0  0.734744     C       0.0          1    3.0
# 3   0.481288 -0.445000    65.0  0.383183     C       2.0          1    3.0
# 6  -0.479087 -0.445000   109.0  0.359257     E       2.0          1    2.0
# 10  0.481288  0.710763   839.0 -0.320583     G       2.0          1    1.0
# 11 -0.479087 -0.445000    50.0 -0.130140     C       2.0          1    1.0
#
#     Cabin_Title  cluster
# 1           2.0        2
# 3           2.0        6
# 6           4.0        4
# 10          6.0        8
# 11          2.0        4

# %%
X_train.head(5)
# Out:
#       Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  Title  \
# 1  -1.546098  0.0  0.563552  0.481288 -0.445000  0.734744       0.0    3.0
# 3  -1.546098  0.0  0.355314  0.481288 -0.445000  0.383183       2.0    3.0
# 6  -1.546098  1.0  1.674153 -0.479087 -0.445000  0.359257       2.0    2.0
# 10  0.841916  0.0 -1.796478  0.481288  0.710763 -0.320583       2.0    1.0
# 11 -1.546098  0.0  1.951804 -0.479087 -0.445000 -0.130140       2.0    1.0
#
#     Ticket  cluster
# 1    816.0        2
# 3     65.0        6
# 6    109.0        4
# 10   839.0        8
# 11    50.0        4

# %%
X_train.shape
# Out:
# (295, 10)

# %%
na_cabin_df = age_df[cabin_con].copy()

X_test = na_cabin_df[feature_cols]
y_test = na_cabin_df["Cabin"]

# %%
X_test.head(5)
# Out:
#      Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  Title  \
# 0  0.841916  1.0 -0.547050  0.481288 -0.445000 -0.503291       2.0    2.0
# 2  0.841916  0.0 -0.269400 -0.479087 -0.445000 -0.490240       2.0    1.0
# 4  0.841916  1.0  0.355314 -0.479087 -0.445000 -0.487824       2.0    2.0
# 5  0.841916  1.0 -0.075069 -0.479087 -0.445000 -0.479930       1.0    2.0
# 7  0.841916  1.0 -1.935303  2.402037  0.710763 -0.235995       2.0    0.0
#
#    Ticket  cluster
# 0   720.0        1
# 2   914.0        0
# 4   649.0        1
# 5   373.0        1
# 7   541.0        5

# %%
from xgboost import XGBClassifier

# %%
xgb_class = XGBClassifier()
xgb_class.fit(X_train,y_train)

# %%
merged_df.groupby(merged_df.Cabin.isna())["Pclass"].value_counts()
# Out:
# Cabin  Pclass
# False  1         256
#        2          23
#        3          16
# True   3         693
#        2         254
#        1          67
# Name: count, dtype: int64

# %%
deck_map = {"A":"ABC", "B":"ABC", "C":"ABC", "T":"ABC",
            "D":"DE",  "E":"DE",
            "F":"FG",  "G":"FG",
            "Unknown":"Unknown"}
age_df["Deck"] = merged_df["Cabin_Title"].map(deck_map).values

# %%
age_df["TicketGroup"] = merged_df.groupby("Ticket")["Ticket"].transform("count").values

# %%
age_df["FamilySize"] = age_df["SibSp"] + age_df["Parch"] + 1
age_df["IsAlone"]    = (age_df["FamilySize"] == 1).astype(int)
age_df["FarePerHead"] = merged_df["Fare"].values / age_df["TicketGroup"]
