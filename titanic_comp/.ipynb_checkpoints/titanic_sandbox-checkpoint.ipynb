# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.2730275158530257, inertia:4673.38325036969
# n_clusters:3, sil_score:0.2667583186030291, inertia:3504.0695929518847
# n_clusters:4, sil_score:0.3091184644824044, inertia:2985.6114592250146
# n_clusters:5, sil_score:0.31150657320299274, inertia:2663.512705605804
# n_clusters:6, sil_score:0.33870272755293956, inertia:2214.1130753814455
# n_clusters:7, sil_score:0.36606548768081515, inertia:2045.8538317081334
# n_clusters:8, sil_score:0.3813465993751282, inertia:1763.775075955462
# n_clusters:9, sil_score:0.3566641024640685, inertia:1926.2892604754566
# n_clusters:10, sil_score:0.42004043029845345, inertia:1472.8439765990147
# n_clusters:11, sil_score:0.4366320413384497, inertia:1352.0602131722424
# n_clusters:12, sil_score:0.4516423507623724, inertia:1343.241671664771
# n_clusters:13, sil_score:0.447843938007348, inertia:1268.152458516636
# n_clusters:14, sil_score:0.45445254287061404, inertia:1268.6174973191262
# n_clusters:15, sil_score:0.4685192834808582, inertia:1140.3238994971964
# n_clusters:16, sil_score:0.48207610944779145, inertia:1077.4839914787854
# n_clusters:17, sil_score:0.4842279914915088, inertia:1137.4400285022432
# n_clusters:18, sil_score:0.5101721796676348, inertia:945.8456843970242
# n_clusters:19, sil_score:0.5299184590269964, inertia:917.0850751697401
# n_clusters:20, sil_score:0.4670482697493047, inertia:1032.7183065525644
# n_clusters:21, sil_score:0.552219943469632, inertia:835.0635464986872
# n_clusters:22, sil_score:0.5499585748591881, inertia:797.6327233719425
# n_clusters:23, sil_score:0.5605247369527032, inertia:758.5987392067861
# n_clusters:24, sil_score:0.5467911989632933, inertia:753.7259159802827
# n_clusters:25, sil_score:0.5802153706240513, inertia:716.7751494728941
# n_clusters:26, sil_score:0.5924456650206713, inertia:709.1866018543834
# n_clusters:27, sil_score:0.5709304855827128, inertia:690.8920945261386
# n_clusters:28, sil_score:0.5854687924387606, inertia:667.4335650899933
# n_clusters:29, sil_score:0.5948954296038435, inertia:655.3763759437968
# n_clusters:30, sil_score:0.5818097786475129, inertia:648.0620426917882
# n_clusters:31, sil_score:0.6066253628958684, inertia:574.4256974529637
# n_clusters:32, sil_score:0.6358673819110761, inertia:570.6000774766646
# n_clusters:33, sil_score:0.6074003403009731, inertia:579.9626200116323
# n_clusters:34, sil_score:0.6165698649724733, inertia:571.077380708381
# n_clusters:35, sil_score:0.6148991751029608, inertia:529.8025852291903
# n_clusters:36, sil_score:0.6315053168947327, inertia:534.1172657579452
# n_clusters:37, sil_score:0.6348707088737501, inertia:483.0832532173766
# n_clusters:38, sil_score:0.6390849458528958, inertia:486.5813896001342
# n_clusters:39, sil_score:0.6369401563625942, inertia:492.0264037361941

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        32.208007  12.902509  166.474751    893
# 1        16.300131  15.292568  233.862650    153
#               mean        std         var  count
# cluster
# 0        31.630812  12.569061  157.981293    702
# 1        33.155707  14.481773  209.721746    205
# 2        16.215252  15.525333  241.035974    139
#               mean        std         var  count
# cluster
# 0        16.292000  15.368064  236.177382    135
# 1        31.826321  12.576815  158.176285    666
# 2        37.858621  13.288427  176.582304    145
# 3        23.704200  12.035990  144.865067    100
#               mean        std         var  count
# cluster
# 0        37.530405  13.929149  194.021178    148
# 1        23.707129  11.975695  143.417283    101
# 2        34.265040  14.647878  214.560339    371
# 3        26.522730  10.804251  116.731846    348
# 4        17.493718  15.628653  244.254787     78
#               mean        std         var  count
# cluster
# 0        26.287582  16.845261  283.762816     91
# 1        27.811678  11.364316  129.147682    435
# 2        10.848837   8.876490   78.792082     43
# 3        30.397791  13.992507  195.790261    172
# 4        33.277778  15.506629  240.455549    171
# 5        40.149254  13.173514  173.541466    134
#               mean        std         var  count
# cluster
# 0        38.166667  13.137070  172.582596    114
# 1        28.229955  10.819873  117.069657    445
# 2        10.654762   8.891273   79.054733     42
# 3        20.418120  16.633140  276.661340    117
# 4        37.810078  13.232180  175.090601    129
# 5        38.571429  13.284780  176.485390    133
# 6        22.703333  11.079033  122.744964     66
#               mean        std         var  count
# cluster
# 0        19.512296  12.724117  161.903157    135
# 1        29.679348  11.044579  121.982733    368
# 2        37.520979  13.570353  184.154486    143
# 3        10.654762   8.891273   79.054733     42
# 4        40.268362  13.087881  171.292630    177
# 5        28.184943  13.430856  180.387902     87
# 6        21.603951  10.645196  113.320202     81
# 7        42.846154   9.281219   86.141026     13
#               mean        std         var  count
# cluster
# 0        28.671946  10.054729  101.097573    221
# 1        28.027162  15.929901  253.761741     74
# 2        18.330698  11.558782  133.605436    129
# 3         9.914634   7.965474   63.448780     41
# 4        35.867647  13.405742  179.713924    204
# 5        37.962963  13.758122  189.285931    135
# 6        25.306250  12.011925  144.286353     80
# 7        40.310345  13.265018  175.960706     87
# 8        28.006667   9.481309   89.895225     75
#               mean        std         var  count
# cluster
# 0        38.951220  13.053235  170.386945    123
# 1        28.562500  10.080422  101.614900    264
# 2        10.785714   5.015452   25.154762      7
# 3         9.668103   8.805462   77.536163     58
# 4        23.048169  10.885814  118.500952     71
# 5        35.632558  13.370436  178.768561    215
# 6        38.166667  13.137070  172.582596    114
# 7        21.382685  10.204801  104.137967    108
# 8        42.846154   9.281219   86.141026     13
# 9        24.290000  16.430713  269.968336     73
#               mean        std         var  count
# cluster
# 0        36.700000  13.547565  183.536508    190
# 1         9.258621   7.363788   54.225369     29
# 2        38.097826  13.027604  169.718462    138
# 3        21.154151  15.253771  232.677544     53
# 4        37.275229  13.516020  182.682807    109
# 5        26.833333  11.778877  138.741935     63
# 6        31.039683   9.113222   83.050819     63
# 7         6.881356   6.859737   47.055998     59
# 8        28.603376   9.922842   98.462785    237
# 9        42.846154   9.281219   86.141026     13
# 10       23.744565   8.556051   73.206014     92
#               mean        std         var  count
# cluster
# 0        29.203704   9.310938   86.693571     54
# 1        28.603376   9.922842   98.462785    237
# 2        26.500000  11.076014  122.678082     74
# 3        38.656250  13.165923  173.341535    128
# 4         8.723684   6.950304   48.306721     38
# 5        34.450000  11.528560  132.907692     40
# 6        40.310345  13.265018  175.960706     87
# 7        24.164773   8.425032   70.981159     88
# 8         9.032561   8.646210   74.756953     82
# 9        42.846154   9.281219   86.141026     13
# 10       32.631818  12.385008  153.388428    110
# 11       39.584211  13.568905  184.115174     95
#               mean        std         var  count
# cluster
# 0        10.761905   8.965543   80.380952     42
# 1        24.448857  12.856955  165.301280     70
# 2        35.886792  13.286094  176.520299    212
# 3        40.311111  13.286737  176.537374     45
# 4        30.486486  18.458093  340.701201     37
# 5        42.846154   9.281219   86.141026     13
# 6        28.462151   9.863649   97.291562    251
# 7        24.072222   8.358055   69.857085     90
# 8        36.690789  12.100404  146.419781     76
# 9        11.786184  11.390747  129.749123     76
# 10       14.500000        NaN         NaN      1
# 11       41.253333  13.678839  187.110631     75
# 12       32.448276   8.940686   79.935874     58
#               mean        std         var  count
# cluster
# 0        36.539683  13.363863  178.592832    189
# 1        20.933158   8.029070   64.465958     76
# 2        38.333333  11.161157  124.571429     36
# 3        14.500000        NaN         NaN      1
# 4        31.171429  10.918106  119.205042     35
# 5        10.268293   8.479459   71.901220     41
# 6        38.174242  13.577553  184.349942     66
# 7        28.178571  11.234455  126.212987     56
# 8        28.671946  10.054729  101.097573    221
# 9        28.156250  11.572232  133.916556     48
# 10       39.752809  13.389515  179.279111     89
# 11       40.500000  13.586602  184.595745     48
# 12       10.450658  11.549516  133.391316     76
# 13       27.976562   8.165175   66.670077     64
#               mean        std         var  count
# cluster
# 0        34.277778  10.943159  119.752739     72
# 1        34.297297  10.518806  110.645270     37
# 2        28.196429  11.252749  126.624351     56
# 3        10.761905   8.965543   80.380952     42
# 4        28.313253   9.654947   93.218009    249
# 5        40.911111  13.735856  188.673737     45
# 6        35.826291  13.284100  176.467324    213
# 7        37.037634  12.691840  161.082807     93
# 8              NaN        NaN         NaN      0
# 9        14.500000        NaN         NaN      1
# 10       42.846154   9.281219   86.141026     13
# 11        9.834559   8.586085   73.720858     68
# 12       22.480263  10.394050  108.036272     76
# 13       44.833333  14.006822  196.191057     42
# 14       17.677436   9.554378   91.286146     39
#               mean        std         var  count
# cluster
# 0        30.067073   9.972110   99.442977     82
# 1        24.580808  10.581970  111.978097     99
# 2        33.032258   9.917943   98.365591     31
# 3        26.936170   7.998381   63.974098     47
# 4        12.431818   9.188561   84.429654     22
# 5        41.868243  13.137856  172.603270    148
# 6        42.846154   9.281219   86.141026     13
# 7        15.259444  12.943876  167.543925     36
# 8        29.890432  11.272361  127.066131    324
# 9        14.500000        NaN         NaN      1
# 10       40.606383  13.509828  182.515443     94
# 11       32.771739   8.560703   73.285628     46
# 12       19.500000   7.790791   60.696429     29
# 13        8.500000   7.290278   53.148148     28
# 14        3.907931   3.654931   13.358524     29
# 15       32.352941  17.563959  308.492647     17
#               mean        std         var  count
# cluster
# 0        29.500000  17.780829  316.157895     20
# 1        28.728311  10.074057  101.486626    219
# 2        36.061798  13.469535  181.428363    178
# 3        14.500000        NaN         NaN      1
# 4        24.164773   8.425032   70.981159     88
# 5        37.060606  10.744008  115.433712     33
# 6        10.050000   8.470007   71.741026     40
# 7        29.312500   9.207488   84.777841     56
# 8        38.083333  13.221425  174.806075    108
# 9        40.391304  13.149530  172.910145     46
# 10       41.500000   2.121320    4.500000      2
# 11        4.397273   4.018083   16.144992     22
# 12       28.816176  11.860792  140.678391     68
# 13       37.658537  12.913740  166.764679     82
# 14       15.362941  10.599120  112.341337     34
# 15       22.052187  16.100202  259.216508     32
# 16        7.142353   5.608737   31.457932     17
#               mean        std         var  count
# cluster
# 0         7.829524   6.550653   42.911055     21
# 1        28.446809   9.705621   94.199082    235
# 2        34.750000  10.295977  106.007143     36
# 3        39.456897  13.806077  190.607759     58
# 4        14.500000        NaN         NaN      1
# 5        27.914286   9.678270   93.668908     35
# 6         4.506400   4.054793   16.441349     25
# 7        24.164773   8.425032   70.981159     88
# 8        45.195122  13.980736  195.460976     41
# 9        42.846154   9.281219   86.141026     13
# 10       27.538462  10.934217  119.557091     65
# 11       40.379121  13.222947  174.846337     91
# 12        9.800000   8.032626   64.523077     40
# 13       40.911111  13.735856  188.673737     45
# 14       32.631818  12.385008  153.388428    110
# 15       34.442857  11.029126  121.641615     70
# 16       12.052250   9.295168   86.400156     40
# 17       32.687500   9.949672   98.995968     32
#               mean        std         var  count
# cluster
# 0        44.833333  12.971689  168.264706     18
# 1        17.065217  13.358734  178.455781     23
# 2         4.712258   4.103223   16.836438     31
# 3        28.425581   9.791115   95.865931    215
# 4        29.201754   9.163134   83.963033     57
# 5        37.400000  13.219709  174.760714     85
# 6        42.846154   9.281219   86.141026     13
# 7        24.891915  14.782699  218.528203     47
# 8        14.500000        NaN         NaN      1
# 9        28.715517  10.393196  108.018527     58
# 10        8.837838   7.562751   57.195195     37
# 11       21.838028   7.344471   53.941247     71
# 12       43.441176  14.571020  212.314617     34
# 13       42.404110  12.689852  161.032344     73
# 14       24.773590  15.866242  251.737624     39
# 15       32.250000  12.838069  164.816011     90
# 16       40.911111  13.735856  188.673737     45
# 17       28.255102  11.471942  131.605442     49
# 18       33.400000  10.441443  109.023729     60

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      31.530702
# 1      38.898438
# 2      20.605484
# 3      37.790909
# 4      28.728311
#          ...
# 413    28.728311
# 414    38.898438
# 415    28.728311
# 416    28.728311
# 417    16.863902
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)
