# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
age_df = merged_df.copy()

# %%
age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df.dropna(subset=["Fare","Embarked"],inplace=True)

# %%
age_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# train_col        0
# dtype: int64

# %%
get_name = age_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
age_df["Title"] = get_title

# %%
age_df["Title"].value_counts()
# Out:
# Title
# Mr              756
# Miss            259
# Mrs             196
# Master           61
# Rev               8
# Dr                8
# Col               4
# Ms                2
# Major             2
# Mlle              2
# Don               1
# Mme               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: count, dtype: int64

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

age_df["Title"] = age_df["Title"].str.strip().map(title_map)

# %%
age_df.head(5)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked  train_col  \
# 0    male  22.0      1      0         A/5 21171   7.2500        S          1
# 1  female  38.0      1      0          PC 17599  71.2833        C          1
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S          1
# 3  female  35.0      1      0            113803  53.1000        S          1
# 4    male  35.0      0      0            373450   8.0500        S          1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'train_col', 'Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

age_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#      Sex   Age  SibSp  Parch  Ticket      Fare  Embarked  train_col  Title
# 0    1.0  22.0      1      0   718.0    7.2500       2.0          1    2.0
# 1    0.0  38.0      1      0   814.0   71.2833       0.0          1    3.0
# 2    0.0  26.0      0      0   912.0    7.9250       2.0          1    1.0
# 3    0.0  35.0      1      0    64.0   53.1000       2.0          1    3.0
# 4    1.0  35.0      0      0   647.0    8.0500       2.0          1    2.0
# ..   ...   ...    ...    ...     ...       ...       ...        ...    ...
# 413  1.0   NaN      0      0   709.0    8.0500       2.0          0    2.0
# 414  0.0  39.0      0      0   832.0  108.9000       0.0          0    4.0
# 415  1.0  38.5      0      0   870.0    7.2500       2.0          0    2.0
# 416  1.0   NaN      0      0   578.0    8.0500       2.0          0    2.0
# 417  1.0   NaN      1      1   261.0   22.3583       0.0          0    0.0
#
# [1306 rows x 12 columns]

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","Age","SibSp","Parch","Ticket","Embarked","Title"]
data = age_not_na[features]

r = range(1,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 15
#      13 model.fit(data)
#      14 iner = model.inertia_
# ---> 15 sil_score = silhouette_score(data, model.predict(data))
#      16 sil_scores.append(sil_score)
#      17 iners.append(iner)
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:146, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     144     else:
#     145         X, labels = X[indices], labels[indices]
# --> 146 return float(np.mean(silhouette_samples(X, labels, metric=metric, **kwds)))
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:304, in silhouette_samples(X, labels, metric, **kwds)
#     302 n_samples = len(labels)
#     303 label_freqs = np.bincount(labels)
# --> 304 check_number_of_labels(len(le.classes_), n_samples)
#     306 kwds["metric"] = metric
#     307 reduce_func = functools.partial(
#     308     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     309 )
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:43, in check_number_of_labels(n_labels, n_samples)
#      32 """Check that number of labels are valid.
#      33
#      34 Parameters
#    (...)     40     Number of samples.
#      41 """
#      42 if not 1 < n_labels < n_samples:
# ---> 43     raise ValueError(
#      44         "Number of labels is %d. Valid values are 2 to n_samples - 1 (inclusive)"
#      45         % n_labels
#      46     )
#
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)

# %%
age_not_na
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 409         1301       3                          Peacock, Miss. Treasteall
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                     Henriksson, Miss. Jenny Lovisa
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# 0      male  22.0      1      0           A/5 21171    7.2500        S
# 1    female  38.0      1      0            PC 17599   71.2833        C
# 2    female  26.0      0      0    STON/O2. 3101282    7.9250        S
# 3    female  35.0      1      0              113803   53.1000        S
# 4      male  35.0      0      0              373450    8.0500        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750        S
# 411  female  37.0      1      0               19928   90.0000        Q
# 412  female  28.0      0      0              347086    7.7750        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
#
#      train_col
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 409          0
# 411          0
# 412          0
# 414          0
# 415          0
#
# [1043 rows x 11 columns]
