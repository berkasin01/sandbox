# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.4270572723670101, inertia:4247.3345820184395
# n_clusters:3, sil_score:0.3058477107951341, inertia:3469.3396612248875
# n_clusters:4, sil_score:0.2874253932579716, inertia:2972.5219983858674
# n_clusters:5, sil_score:0.319556993132088, inertia:2469.10327240657
# n_clusters:6, sil_score:0.3306982801686768, inertia:2248.8491964416617
# n_clusters:7, sil_score:0.35537784444103765, inertia:1981.4264641949594
# n_clusters:8, sil_score:0.38378137267534473, inertia:1781.48092021494
# n_clusters:9, sil_score:0.38175073317839475, inertia:1669.4389665744577
# n_clusters:10, sil_score:0.3902608452420496, inertia:1587.9807356544723
# n_clusters:11, sil_score:0.4331586103934343, inertia:1399.4600122322372
# n_clusters:12, sil_score:0.4411331124092378, inertia:1304.9935084370886
# n_clusters:13, sil_score:0.44624646868545464, inertia:1258.156412167286
# n_clusters:14, sil_score:0.40462645815811304, inertia:1351.1962031026017
# n_clusters:15, sil_score:0.44356141837984375, inertia:1196.5407335477987
# n_clusters:16, sil_score:0.46567872897461793, inertia:1128.4576571086309
# n_clusters:17, sil_score:0.5237299671793545, inertia:989.2451339071135
# n_clusters:18, sil_score:0.5046863175500652, inertia:1077.7324287765598
# n_clusters:19, sil_score:0.5409349726649921, inertia:875.6271106981393
# n_clusters:20, sil_score:0.5267088923687356, inertia:888.6589577991335
# n_clusters:21, sil_score:0.5249267822044985, inertia:854.8712352544059
# n_clusters:22, sil_score:0.5470425193679387, inertia:794.2904889227614
# n_clusters:23, sil_score:0.529525911292444, inertia:799.1578456099104
# n_clusters:24, sil_score:0.5562954019746665, inertia:749.8618814363491
# n_clusters:25, sil_score:0.5674286609825195, inertia:745.754130627091
# n_clusters:26, sil_score:0.5797490520804855, inertia:718.0802203829884
# n_clusters:27, sil_score:0.5819306102383582, inertia:663.1111570829212
# n_clusters:28, sil_score:0.5913239187537928, inertia:647.4483804093682
# n_clusters:29, sil_score:0.5903359384998644, inertia:628.16263730154
# n_clusters:30, sil_score:0.6047344057739101, inertia:622.0030523477506
# n_clusters:31, sil_score:0.6141121008652881, inertia:579.5459778063205
# n_clusters:32, sil_score:0.6189563008004058, inertia:556.7636104513022
# n_clusters:33, sil_score:0.6181209747480503, inertia:544.3374366692227
# n_clusters:34, sil_score:0.6366542120056523, inertia:549.0729626828736
# n_clusters:35, sil_score:0.6003985663949242, inertia:548.3705315836082
# n_clusters:36, sil_score:0.6403228180873315, inertia:511.4248065547293
# n_clusters:37, sil_score:0.6416980116844465, inertia:494.5746707966256
# n_clusters:38, sil_score:0.6812996832922893, inertia:459.83059359503125
# n_clusters:39, sil_score:0.6499522356995366, inertia:475.34222462087763

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        38.011682  14.721471  216.721694    214
# 1        27.789868  13.575587  184.296574    832
#               mean        std         var  count
# cluster
# 0        28.960844  12.826153  164.510202    711
# cluster
# 0        19.850000   7.891670   62.278448     30
# 1        18.489487  13.240976  175.323447     39
# 2        41.278689  14.118701  199.337705     61
# 3        10.026316   8.162163   66.620910     38
# 4        28.381743   9.687488   93.847415    241
# 5        39.936170  14.014595  196.408881     47
# 6        42.846154   9.281219   86.141026     13
# 7        40.379121  13.222947  174.846337     91
# 8        28.431818  10.602934  112.422203     66
# 9        33.758621   9.936963   98.743227     29
# 10       35.963636  12.081074  145.952357     55
# 11       32.631818  12.385008  153.388428    110
# 12       34.660000  11.285913  127.371837     50
# 13       22.547297  10.522048  110.713486     74
# 14       20.446429  10.979011  120.538690     28
# 15       14.500000        NaN         NaN      1
# 16       36.523810  16.996754  288.889663     42
# 17        4.712258   4.103223   16.836438     31
#               mean        std         var  count
# cluster
# 0        32.430328  12.325361  151.914527    122
# 1         8.657692   8.424335   70.969412     65
# 2        40.823529  14.621197  213.779412     17
# 3        38.376923  13.582224  184.476803     65
# 4         7.272727   8.403462   70.618182     11
# 5        28.313253   9.654947   93.218009    249
# 6        44.964286  12.309232  151.517196     28
# 7        14.500000        NaN         NaN      1
# 8        39.875000   1.552648    2.410714      8
# 9        29.397727  11.155653  124.448599     44
# 10       28.196429  11.252749  126.624351     56
# 11       40.893617  13.454002  181.010176     47
# 12       36.636364  13.033266  169.866029     77
# 13       10.087273  10.072910  101.463516     22
# 14       31.300000   7.606259   57.855172     30
# 15       42.404110  12.689852  161.032344     73
# 16       12.000000   8.959167   80.266667     31
# 17       22.572464   6.469541   41.854966     69
# 18       33.032258   9.917943   98.365591     31

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      29.403226
# 1      40.500000
# 2      18.519380
# 3      39.715909
# 4      29.529412
#          ...
# 413    29.529412
# 414    40.500000
# 415    29.529412
# 416    29.529412
# 417    18.519380
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
known = age_df["Cabin_Title"] != "Unknown"

# %%
cluster_mode = age_df[known].groupby("cluster")["Cabin_Title"].agg(lambda s: s.mode()[0])

# %%
age_df["Has_Cabin"] = known.astype(int)
age_df["Deck_imputed"] = age_df["Cabin_Title"].where(known, age_df["cluster"].map(cluster_mode))
age_df["Deck_imputed"] = age_df["Deck_imputed"].fillna(age_df.loc[known, "Cabin_Title"].mode()[0])

# %%
age_df["Deck_imputed"]
# Out:
# 0      F
# 1      C
# 2      E
# 3      C
# 4      F
#       ..
# 413    F
# 414    C
# 415    F
# 416    F
# 417    E
# Name: Deck_imputed, Length: 1309, dtype: str

# %%
age_df.shape
# Out:
# (1309, 18)

# %%
age_df.Deck_imputed.value_counts()
# Out:
# Deck_imputed
# F    620
# C    278
# E    204
# B    133
# D     46
# A     22
# G      5
# T      1
# Name: count, dtype: int64

# %%
today="I cannot"
