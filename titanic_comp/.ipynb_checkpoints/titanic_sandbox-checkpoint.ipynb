# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.23487813008221484, inertia:4694.118651044162
# n_clusters:3, sil_score:0.3057945104932635, inertia:3469.671118683938
# n_clusters:4, sil_score:0.2916867129743368, inertia:3037.189918747071
# n_clusters:5, sil_score:0.29905989215053114, inertia:2696.3780202902817
# n_clusters:6, sil_score:0.3368169598409701, inertia:2215.4931102216997
# n_clusters:7, sil_score:0.3666098548665895, inertia:2000.0387042981597
# n_clusters:8, sil_score:0.3599689189505922, inertia:1870.8651112583186
# n_clusters:9, sil_score:0.3726416264840865, inertia:1712.0410396584975
# n_clusters:10, sil_score:0.388058765655055, inertia:1587.420693765064
# n_clusters:11, sil_score:0.4294820459580864, inertia:1596.894654213891
# n_clusters:12, sil_score:0.41226766330070047, inertia:1456.2019699033424
# n_clusters:13, sil_score:0.4546351096453416, inertia:1236.3330404196695
# n_clusters:14, sil_score:0.44182050407069345, inertia:1174.104687978496
# n_clusters:15, sil_score:0.46492474278141077, inertia:1117.7494390249815
# n_clusters:16, sil_score:0.4794877016544816, inertia:1061.5148773378983
# n_clusters:17, sil_score:0.45655769864791995, inertia:1034.7329339777386
# n_clusters:18, sil_score:0.5354797073424792, inertia:1032.797777077151
# n_clusters:19, sil_score:0.5440368613376847, inertia:941.0678331709408
# n_clusters:20, sil_score:0.5230688163796123, inertia:892.7015143009583
# n_clusters:21, sil_score:0.5151953015605972, inertia:862.7592420970025
# n_clusters:22, sil_score:0.5354412354665371, inertia:861.8097115732733
# n_clusters:23, sil_score:0.5216057981234682, inertia:817.5508599909439
# n_clusters:24, sil_score:0.5544177373579032, inertia:756.2140143633426
# n_clusters:25, sil_score:0.541311297113971, inertia:782.9622905961444
# n_clusters:26, sil_score:0.5696812438573245, inertia:729.632126686025
# n_clusters:27, sil_score:0.5692728399628437, inertia:674.0756472652582
# n_clusters:28, sil_score:0.5909915074675769, inertia:661.2714579019278
# n_clusters:29, sil_score:0.5887579223215998, inertia:632.6263124829202
# n_clusters:30, sil_score:0.5850496913774608, inertia:632.4211815918301
# n_clusters:31, sil_score:0.5906327673654648, inertia:613.8894605488101
# n_clusters:32, sil_score:0.6116131051454122, inertia:583.9157049954332
# n_clusters:33, sil_score:0.6166212492887503, inertia:552.8785826736984
# n_clusters:34, sil_score:0.6231807886237772, inertia:552.8580241476451
# n_clusters:35, sil_score:0.6196902131468667, inertia:538.9805624653445
# n_clusters:36, sil_score:0.6281547711920139, inertia:505.25223446356443
# n_clusters:37, sil_score:0.6282464240398347, inertia:512.2488826848885
# n_clusters:38, sil_score:0.6406474134404136, inertia:499.83652502266216
# n_clusters:39, sil_score:0.6413618180797136, inertia:466.0769402692751

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        29.107920  14.055635  197.560868    827
# 1        32.801005  15.377611  236.470914    219
#               mean        std         var  count
# cluster
# 0        31.630812  12.569061  157.981293    702
# 1        16.215252  15.525333  241.035974    139
# 2        33.155707  14.481773  209.721746    205
#               mean        std         var  count
# cluster
# 0        19.151477  12.072547  145.746400    176
# 1        34.765625  13.629724  185.769388    192
# 2        19.930215  16.321538  266.392596     93
# 3        33.088034  12.519418  156.735815    585
#               mean        std         var  count
# cluster
# 0        30.239351  10.744563  115.445643    493
# 1        14.500000        NaN         NaN      1
# 2        26.496719  16.072706  258.331885    256
# 3        38.702500  13.868559  192.336928    200
# 4        18.849062  16.437851  270.202943     96
#               mean        std         var  count
# cluster
# 0        37.572519  12.665538  160.415854    131
# 1        28.140421  10.853015  117.787924    451
# 2        37.925781  13.218498  174.728700    128
# 3        15.667313  15.642102  244.675366    134
# 4        33.912410  14.025358  196.710672    195
# 5        10.785714   5.015452   25.154762      7
#               mean        std         var  count
# cluster
# 0        27.909333   9.805858   96.154859    375
# 1        40.014925  14.213195  202.014925     67
# 2        10.848837   8.876490   78.792082     43
# 3        36.800676  13.332227  177.748271    296
# 4        37.641026  11.065563  122.446694     39
# 5        11.444479  11.278883  127.213202     96
# 6        32.173077  12.930900  167.208184    130
#               mean        std         var  count
# cluster
# 0        36.417460  13.340334  177.964503    315
# 1        24.151789  11.848423  140.385134     95
# 2        16.835586  14.871620  221.165074    111
# 3        10.369048   8.400827   70.573897     42
# 4        41.631579  10.382734  107.801170     19
# 5        40.836735  13.649400  186.306122     49
# 6        36.500000  12.735081  162.182292     97
# 7        27.839623   9.533160   90.881138    318
#               mean        std         var  count
# cluster
# 0         8.614286   6.962173   48.471849     35
# 1        32.878713  11.775529  138.663077    202
# 2        24.224962   8.886505   78.969966    133
# 3        38.386029  12.940743  167.462840    136
# 4        20.083400  14.502979  210.336407     50
# 5        28.702000  10.145933  102.939956    250
# 6        37.685714  10.615669  112.692437     35
# 7        41.912214  13.639941  186.048004    131
# 8        11.906486  10.919120  119.227190     74
#               mean        std         var  count
# cluster
# 0        24.657882  12.316922  151.706579     85
# 1        36.032609  13.720931  188.263958    184
# 2        29.284946   9.958446   99.170640     93
# 3         9.687500   7.931346   62.906250     40
# 4        38.968750  13.300102  176.892717    128
# 5        28.671946  10.054729  101.097573    221
# 6        42.846154   9.281219   86.141026     13
# 7        22.508933  15.337691  235.244777     75
# 8        19.479664  11.233262  126.186186    119
# 9        40.125000  13.302677  176.961207     88
#               mean        std         var  count
# cluster
# 0        32.937500   9.771379   95.479839     32
# 1        27.654237   9.596490   92.092627    295
# 2        10.761905   8.965543   80.380952     42
# 3        37.429688  12.599640  158.750923    128
# 4        11.827922  11.471577  131.597088     77
# 5        17.540571  15.583545  242.846876     35
# 6        40.335000  13.527199  182.985126    100
# 7        40.833333  11.464780  131.441176     18
# 8        26.789157  10.470959  109.640979     83
#               mean        std         var  count
# cluster
# 0        28.374486   9.672194   93.551330    243
# 1        36.798913  12.574189  158.110219     92
# 2        25.285714  19.429727  377.514286     21
# 3        24.164773   8.425032   70.981159     88
# 4        31.038462   9.517706   90.586727     52
# 5        40.141026  12.350660  152.538799     39
# 6        10.560976   8.980670   80.652439     41
# 7        14.500000        NaN         NaN      1
# 8        13.171818  10.308333  106.261728     33
# 9              NaN        NaN         NaN      0
# 10       40.005952  13.227047  174.954783     84
# 11       39.835821  13.850497  191.836273     67
# 12       40.833333  11.464780  131.441176     18
# 13        6.602273   6.654218   44.278613     44
# 14       32.282609  12.248546  150.026888    115
# 15       40.311111  13.286737  176.537374     45
# 16       26.579365  11.645713  135.622632     63
#               mean        std         var  count
# cluster
# 0        39.527397  13.747952  189.006183     73
# 1        32.631818  12.385008  153.388428    110
# 2        14.500000        NaN         NaN      1
# 3         8.478723   7.517681   56.515529     47
# 4        34.233333   9.338217   87.202299     30
# 5        17.095000   9.587859   91.927043     36
# 6        39.250000  14.425316  208.089744     40
# 7        42.846154   9.281219   86.141026     13
# 8        40.379121  13.222947  174.846337     91
# 9        34.442857  11.029126  121.641615     70
# 10       28.220339  10.694533  114.373027     59
# 11       27.914286   9.678270   93.668908     35
# 12       28.446809   9.705621   94.199082    235
# 13       25.161538   8.121686   65.961779     65
# 14       45.195122  13.980736  195.460976     41
# 15       33.032258   9.917943   98.365591     31
# 16        9.698276   9.737690   94.822608     29
# 17        9.800000   8.032626   64.523077     40
#               mean        std         var  count
# cluster
# 0        28.313253   9.654947   93.218009    249
# 1        52.666667  15.307950  234.333333      3
# 2         6.144762   6.389658   40.827728     42
# 3        41.187500  13.147887  172.866935     32
# 4        42.846154   9.281219   86.141026     13
# 5        10.761905   8.965543   80.380952     42
# 6        31.995763  11.901752  141.651691    118
# 7        26.027778   9.676904   93.642478     90
# 8        31.656250  18.976402  360.103831     32
# 9        28.956140  10.321303  106.529292     57
# 10       38.282051  13.427920  180.309024     78
# 11       14.500000        NaN         NaN      1
# 12       40.755556  13.061316  170.597980     45
# 13       41.949275  12.768915  163.045183     69
# 14       38.365079  12.361558  152.808116     63
# 15       21.236842  13.707377  187.892178     19
# 16       18.654857   8.659909   74.994032     35
# 17       15.236250  10.982085  120.606181     24
# 18       32.735294   9.657965   93.276292     34

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.526531
# 1      38.968750
# 2      24.072222
# 3      41.197368
# 4      28.526531
#          ...
# 413    28.526531
# 414    38.968750
# 415    28.526531
# 416    28.526531
# 417    24.824651
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64
