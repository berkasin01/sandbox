# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.478960904689114, inertia:4264.381393850836
# n_clusters:3, sil_score:0.30576774917191935, inertia:3469.7010832825436
# n_clusters:4, sil_score:0.28985620655515076, inertia:3173.967666200276
# n_clusters:5, sil_score:0.30361236881515863, inertia:2638.324915920481
# n_clusters:6, sil_score:0.33321122600063563, inertia:2252.869493466334
# n_clusters:7, sil_score:0.3586692953704952, inertia:2101.2714546612883
# n_clusters:8, sil_score:0.38514983069903824, inertia:1807.470204568352
# n_clusters:9, sil_score:0.3973155863935723, inertia:1697.1837135720727
# n_clusters:10, sil_score:0.4267609127062037, inertia:1529.9756396113773
# n_clusters:11, sil_score:0.4491241888847606, inertia:1414.1008363791764
# n_clusters:12, sil_score:0.4342816880277218, inertia:1346.9476380790518
# n_clusters:13, sil_score:0.452503013047661, inertia:1256.9184662872547
# n_clusters:14, sil_score:0.4278197074876029, inertia:1269.7040152149589
# n_clusters:15, sil_score:0.44193637542037345, inertia:1201.7536930029485
# n_clusters:16, sil_score:0.48429433456757576, inertia:1053.2120663649039
# n_clusters:17, sil_score:0.4911290677081926, inertia:1010.6416205794118
# n_clusters:18, sil_score:0.4730585623929424, inertia:1043.3046317923292
# n_clusters:19, sil_score:0.5202120909802003, inertia:934.3072617919674
# n_clusters:20, sil_score:0.5246314425025427, inertia:879.4374477553731
# n_clusters:21, sil_score:0.5308417699006236, inertia:845.5222323797159
# n_clusters:22, sil_score:0.5484582719528878, inertia:810.4756846785175
# n_clusters:23, sil_score:0.5652643266003369, inertia:767.0565270788184
# n_clusters:24, sil_score:0.5576577242598318, inertia:730.0607453640339
# n_clusters:25, sil_score:0.5939728498357763, inertia:725.4593085485079
# n_clusters:26, sil_score:0.5936199627255397, inertia:712.9656707882774
# n_clusters:27, sil_score:0.5696358340306351, inertia:701.6367861717937
# n_clusters:28, sil_score:0.604865740051817, inertia:679.2607225510169
# n_clusters:29, sil_score:0.6020143967553826, inertia:637.1250634340731
# n_clusters:30, sil_score:0.6051318261464025, inertia:593.9590010556572
# n_clusters:31, sil_score:0.6229876699358518, inertia:576.9869797755753
# n_clusters:32, sil_score:0.6083526662942736, inertia:587.9942301298577
# n_clusters:33, sil_score:0.6200697228761543, inertia:550.7655800091721
# n_clusters:34, sil_score:0.6102152974043319, inertia:536.9274853835667
# n_clusters:35, sil_score:0.6345768268445839, inertia:519.2218254871551
# n_clusters:36, sil_score:0.652890144971381, inertia:515.8552085776248
# n_clusters:37, sil_score:0.6211536795287045, inertia:530.5753041952071
# n_clusters:38, sil_score:0.6387227934941144, inertia:489.4633729482349
# n_clusters:39, sil_score:0.6664218284831905, inertia:469.3764494647544

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        16.300131  15.292568  233.862650    153
# 1        32.208007  12.902509  166.474751    893
#               mean        std         var  count
# cluster
# 0        38.133772  13.743668  188.888414    228
# 1        15.628811  15.367380  236.156353    143
# 2        30.112963  11.939123  142.542659    675
#               mean        std         var  count
# cluster
# 0        33.089615  12.441774  154.797744    597
# 1        18.976190  16.406733  269.180876     63
# 2        37.416129  13.410577  179.843569    155
# 3        19.507229  12.006396  144.153557    231
#               mean        std         var  count
# cluster
# 0        38.646667  13.093101  171.429286    225
# 1        16.807133  15.872621  251.940109    143
# 2        28.140233  10.666075  113.765164    473
# 3        34.196566  14.190459  201.369117    198
# 4        10.785714   5.015452   25.154762      7
#               mean        std         var  count
# cluster
# 0        28.926174  10.051027  101.023151    298
# 1        37.003226  13.707697  187.900964    155
# 2        11.184783   8.770759   76.926208     46
# 3        18.391931  11.426612  130.567467    202
# 4        40.350000  11.617931  134.976316     20
# 5        36.503077  13.444616  180.757707    325
#               mean        std         var  count
# cluster
# 0        19.251453  12.196619  148.757505    172
# 1        29.297450  10.564704  111.612976    353
# 2        37.536232  14.473187  209.473130    138
# 3        11.184783   8.770759   76.926208     46
# 4        40.350000  11.617931  134.976316     20
# 5        38.871111  12.596017  158.659653    225
# 6        25.596957  13.392846  179.368314     92
#               mean        std         var  count
# cluster
# 0        36.590615  13.448189  180.853775    309
# 1        38.332143  13.032970  169.858312    140
# 2        27.848684   9.652295   93.166797    304
# 3        14.500000        NaN         NaN      1
# 4        42.846154   9.281219   86.141026     13
# 5        10.534884   8.982387   80.683278     43
# 6        20.026596  14.966286  223.989707    141
# 7        23.878105  11.749595  138.052977     95
#               mean        std         var  count
# cluster
# 0        40.350000  11.617931  134.976316     20
# 1        37.793103  12.793171  163.665230    145
# 2        31.497674  11.903115  141.684144    430
# 3        38.679389  13.291418  176.661803    131
# 4        14.500000        NaN         NaN      1
# 5        26.417722  11.272962  127.079682     79
# 6        11.763000  12.278521  150.762077     90
# 7        10.761905   8.965543   80.380952     42
# 8        25.421296   9.584148   91.855897    108
#               mean        std         var  count
# cluster
# 0        27.534014   9.387680   88.128532    294
# 1        24.251828  11.590614  134.342322     93
# 2        39.584211  13.568905  184.115174     95
# 3        42.846154   9.281219   86.141026     13
# 4        38.244361  12.885806  166.044002    133
# 5         8.404930   8.185804   67.007385     71
# 6        38.166667  13.137070  172.582596    114
# 7        31.848276  12.011615  144.278903    145
# 8        10.158537   8.392287   70.430488     41
# 9        32.319149  13.602839  185.037234     47
#               mean        std         var  count
# cluster
# 0        35.645933  13.141299  172.693745    209
# 1        10.785714   5.015452   25.154762      7
# 2        38.612403  13.123845  172.235314    129
# 3        28.313253   9.654947   93.218009    249
# 4        22.861386   8.721846   76.070594    101
# 5         8.724583   8.451030   71.419910     72
# 6        38.166667  13.137070  172.582596    114
# 7        10.967391   9.229272   85.179469     46
# 8        29.485507  11.795740  139.139493     69
# 9        36.976190  12.113766  146.743322     42
# 10       39.875000   1.552648    2.410714      8
#               mean        std         var  count
# cluster
# 0        24.656780   7.796476   60.785039    118
# 1        28.562500  10.080422  101.614900    264
# 2        14.500000        NaN         NaN      1
# 3        17.646486  15.177247  230.348818     37
# 4         9.257246   8.570720   73.457244     69
# 5        10.761905   8.965543   80.380952     42
# 6        35.886792  13.286094  176.520299    212
# 7        42.846154   9.281219   86.141026     13
# 8        39.980392  13.792012  190.219608     51
# 9        36.798913  12.574189  158.110219     92
# 10       39.184466  13.320887  177.446031    103
# 11       32.318182   9.189283   84.442918     44
#               mean        std         var  count
# cluster
# 0        10.369048   8.400827   70.573897     42
# 1        32.508264  12.346387  152.433264    121
# 2        14.933544  14.148847  200.189869     79
# 3        28.381743   9.687488   93.847415    241
# 4        39.032258  13.252204  175.620902    124
# 5        18.136667  15.770233  248.700257     36
# 6        28.059701  10.839575  117.496382     67
# 7        41.109375  13.456712  181.083085     64
# 8        28.290000  11.356959  128.980510     50
# 9        42.846154   9.281219   86.141026     13
# 10       42.404110  12.689852  161.032344     73
# 11       33.463768  11.272794  127.075874     69
# 12       22.194030   7.232060   52.302691     67
#               mean        std         var  count
# cluster
# 0        40.744681  13.229526  175.020352     47
# 1        36.662162  13.531288  183.095756    222
# 2        31.556122  11.186766  125.143725     98
# 3        12.115238   8.084530   65.359626     21
# 4        10.268293   8.479459   71.901220     41
# 5        28.728311  10.074057  101.486626    219
# 6        42.846154   9.281219   86.141026     13
# 7        25.285714  19.429727  377.514286     21
# 8        14.500000        NaN         NaN      1
# 9        24.164773   8.425032   70.981159     88
# 10       36.015625  11.604928  134.674355     64
# 11       37.887500  12.990497  168.753006     80
# 12        9.150000   8.514873   72.503066     65
# 13       30.037879  11.757587  138.240851     66
#               mean        std         var  count
# cluster
# 0        28.313253   9.654947   93.218009    249
# 1        31.552632  12.177957  148.302632     19
# 2         9.421053   8.280983   68.574680     38
# 3        35.592784  13.087060  171.271139    194
# 4         5.997805   6.230060   38.813643     41
# 5        42.846154   9.281219   86.141026     13
# 6        17.260500   9.792798   95.898897     40
# 7        40.500000  13.280243  176.364865     38
# 8        14.500000        NaN         NaN      1
# 9        37.529412  13.310029  177.156863     85
# 10       23.709459   8.951929   80.137033     74
# 11       20.400952  15.015716  225.471726     42
# 12       31.729730   9.145122   83.633258     37
# 13       39.848739  12.978071  168.430316    119
# 14       28.196429  11.252749  126.624351     56
#               mean        std         var  count
# cluster
# 0        32.849138  12.472791  155.570521    116
# 1         9.800000   8.032626   64.523077     40
# 2        37.794118  12.389582  153.501751     85
# 3        32.528302   8.945033   80.013607     53
# 4        28.196429  11.252749  126.624351     56
# 5        17.677436   9.554378   91.286146     39
# 6        28.701961   9.947866   98.960036    255
# 7        42.846154   9.281219   86.141026     13
# 8        25.086957  18.865344  355.901186     23
# 9        39.654255  13.624383  185.623799     94
# 10       40.311111  13.286737  176.537374     45
# 11        8.737903   8.476969   71.859010     62
# 12       41.078947  13.672126  186.927018     76
# 13       14.500000        NaN         NaN      1
# 14       25.950000   6.621138   43.839474     20
# 15       24.360294   8.908677   79.364519     68
#               mean        std         var  count
# cluster
# 0        28.603376   9.922842   98.462785    237
# 1         7.153684   6.527602   42.609591     19
# 2        40.054054  13.601613  185.003887     74
# 3         8.274590   8.433623   71.125989     61
# 4        42.404110  12.689852  161.032344     73
# 5         9.800000   8.032626   64.523077     40
# 6        33.588235  15.878676  252.132353     17
# 7        42.846154   9.281219   86.141026     13
# 8        39.160000  13.237321  175.226667    100
# 9        25.838889   9.757114   95.201280     90
# 10       21.740000   6.967364   48.544167     25
# 11       36.803922  12.196753  148.760784     51
# 12       14.500000        NaN         NaN      1
# 13       28.330645  10.444994  109.097898     62
# 14       32.631818  12.385008  153.388428    110
# 15       32.475000   9.054642   81.986538     40
# 16       28.333333   9.787322   95.791667     33
#               mean        std         var  count
# cluster
# 0        10.706316   8.494026   72.148480     19
# 1        29.721429   9.875176   97.519099     70
# 2        21.454545  15.737621  247.672727     11
# 3        32.250000  12.838069  164.816011     90
# 4        37.666667  13.141568  172.700803     84
# 5        33.794118   9.784123   95.729055     34
# 6         8.837838   7.562751   57.195195     37
# 7        28.559908   9.845619   96.936209    217
# 8        28.253846  10.585634  112.055649     65
# 9              NaN        NaN         NaN      0
# 10       24.770588   7.799784   60.836625     85
# 11       14.500000        NaN         NaN      1
# 12       38.302752  13.379437  179.009344    109
# 13       40.893617  13.454002  181.010176     47
# 14       42.846154   9.281219   86.141026     13
# 15       14.617407  10.914580  119.128058     27
# 16        6.871304   6.762470   45.731003     46
# 17       40.379121  13.222947  174.846337     91
#               mean        std         var  count
# cluster
# 0        26.720238   9.539187   90.996092     84
# 1         8.500000   7.290278   53.148148     28
# 2        28.728311  10.074057  101.486626    219
# 3        30.666667  18.686894  349.200000     36
# 4        32.000000   8.478346   71.882353     52
# 5        28.253846  10.585634  112.055649     65
# 6              NaN        NaN         NaN      0
# 7        42.404110  12.689852  161.032344     73
# 8        38.365079  12.361558  152.808116     63
# 9        39.947368  11.792058  139.052632     19
# 10       13.298333  14.157068  200.422588     24
# 11       12.431818   9.188561   84.429654     22
# 12       40.391304  13.149530  172.910145     46
# 13       14.500000        NaN         NaN      1
# 14       10.534565  10.413344  108.437736     46
# 15       32.250000  12.838069  164.816011     90
# 16       18.654857   8.659909   74.994032     35
# 17       29.721429   9.875176   97.519099     70
# 18       41.369863  13.799665  190.430746     73

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.701128
# 1      38.653846
# 2      22.179012
# 3      38.072727
# 4      28.701128
#          ...
# 413    28.701128
# 414    38.653846
# 415    28.701128
# 416    28.701128
# 417    21.554444
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
known = age_df["Cabin_Title"] != "Unknown"

# %%
cluster_mode = age_df[known].groupby("cluster")["Cabin_Title"].agg(lambda s: s.mode()[0])

# %%
age_df["Has_Cabin"] = known.astype(int)
age_df["Deck_imputed"] = age_df["Cabin_Title"].where(known, age_df["cluster"].map(cluster_mode))
age_df["Deck_imputed"] = age_df["Deck_imputed"].fillna(age_df.loc[known, "Cabin_Title"].mode()[0])
