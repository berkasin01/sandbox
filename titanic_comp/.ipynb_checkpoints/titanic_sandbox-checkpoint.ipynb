# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# ...

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# ...

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

encoders = {}
scalers  = {}

or_cols = ['Title', 'Embarked', 'Sex', 'Ticket', 'Cabin_Title']
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])
    encoders[col] = enc                      

scale_cols = ["Fare", "SibSp", "Parch", "Age", "Pclass"]
sc = StandardScaler()
age_df[scale_cols] = sc.fit_transform(age_df[scale_cols])
scalers["standard"] = (sc, scale_cols)

# %%
def untransform(df):
    out = df.copy()
    s, cols = scalers["standard"]
    out[cols] = s.inverse_transform(out[cols])
    for col, enc in encoders.items():
        out[col] = enc.inverse_transform(out[[col]]).ravel()
    return out

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.22131275534519051, inertia:5079.599262931954
# n_clusters:3, sil_score:0.3390937882005052, inertia:3589.542493882627
# n_clusters:4, sil_score:0.3516687883125692, inertia:3053.232790768775
# n_clusters:5, sil_score:0.3299947641951509, inertia:2860.402637542523
# n_clusters:6, sil_score:0.35515056747202683, inertia:2308.2516310564556
# n_clusters:7, sil_score:0.34694964866248557, inertia:2184.9285705706075
# n_clusters:8, sil_score:0.38899013917155245, inertia:1857.404610526607
# n_clusters:9, sil_score:0.3783980235416253, inertia:1844.2939415310136
# n_clusters:10, sil_score:0.3983720222956233, inertia:1731.266964485674
# n_clusters:11, sil_score:0.43227830493334013, inertia:1554.1548196350182
# n_clusters:12, sil_score:0.42597129224228397, inertia:1547.974266769507
# n_clusters:13, sil_score:0.4801366461326246, inertia:1419.8846105974499
# n_clusters:14, sil_score:0.47869412066744643, inertia:1275.5304308856187
# ...

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#                  mean       std       var  count
# cluster
# 0        1.090056e-16  1.000478  1.000957   1046
#              mean       std       var  count
# cluster
# 0        0.089945  0.943375  0.889957    941
# 1       -0.806079  1.133419  1.284639    105
#              mean       std       var  count
# cluster
# 0       -0.220205  0.834722  0.696762    614
# 1        0.549422  0.973603  0.947904    359
# 2       -0.849813  1.109768  1.231585     73
#              mean       std       var  count
# cluster
# 0       -0.767554  1.147352  1.316417     82
# 1        0.487302  0.931751  0.868159    467
# 2       -0.725038  0.791631  0.626680    200
# 3       -0.066070  0.698603  0.488046    297
#              mean       std       var  count
# cluster
# 0        0.680224  0.910748  0.829463     94
# 1       -1.411149  0.569993  0.324893     39
# 2       -0.117766  0.752198  0.565801    546
# 3        0.607157  0.926846  0.859044    234
# 4       -0.651733  1.156379  1.337213    133
# ...

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0     -0.145253
# 1      0.579899
# 2     -0.145253
# 3      0.723919
# 4     -0.145253
#          ...
# 413   -0.145253
# 414    0.579899
# 415   -0.145253
# 416   -0.145253
# 417   -1.192301
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived    Pclass  \
# 1             2       1.0 -1.546098
# 3             4       1.0 -1.546098
# 6             7       0.0 -1.546098
# 10           11       1.0  0.841916
# 11           12       1.0 -1.546098
#
#                                                  Name  Sex       Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  0.563552
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  0.355314
# 6                             McCarthy, Mr. Timothy J  1.0  1.674153
# 10                    Sandstrom, Miss. Marguerite Rut  0.0 -1.796478
# 11                           Bonnell, Miss. Elizabeth  0.0  1.951804
#
#        SibSp     Parch  Ticket      Fare Cabin  Embarked  train_col  Title  \
# 1   0.481288 -0.445000   816.0  0.734744   C85       0.0          1    3.0
# 3   0.481288 -0.445000    65.0  0.383183  C123       2.0          1    3.0
# 6  -0.479087 -0.445000   109.0  0.359257   E46       2.0          1    2.0
# ...

# %%
cabin_df = age_df[~cabin_con].copy()
cabin_df["Cabin"] = cabin_df["Cabin"].str[0]       

feature_cols = ["Pclass", "Sex", "Age", "SibSp", "Parch",
                "Fare", "Embarked", "Title", "Ticket", "cluster"]

X_train = cabin_df[feature_cols]      
y_train = cabin_df["Cabin"]

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived    Pclass  \
# 1             2       1.0 -1.546098
# 3             4       1.0 -1.546098
# 6             7       0.0 -1.546098
# 10           11       1.0  0.841916
# 11           12       1.0 -1.546098
#
#                                                  Name  Sex       Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  0.563552
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  0.355314
# 6                             McCarthy, Mr. Timothy J  1.0  1.674153
# 10                    Sandstrom, Miss. Marguerite Rut  0.0 -1.796478
# 11                           Bonnell, Miss. Elizabeth  0.0  1.951804
#
#        SibSp     Parch  Ticket      Fare Cabin  Embarked  train_col  Title  \
# 1   0.481288 -0.445000   816.0  0.734744     C       0.0          1    3.0
# 3   0.481288 -0.445000    65.0  0.383183     C       2.0          1    3.0
# 6  -0.479087 -0.445000   109.0  0.359257     E       2.0          1    2.0
# ...

# %%
X_train.head(5)
# Out:
#       Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  Title  \
# 1  -1.546098  0.0  0.563552  0.481288 -0.445000  0.734744       0.0    3.0
# 3  -1.546098  0.0  0.355314  0.481288 -0.445000  0.383183       2.0    3.0
# 6  -1.546098  1.0  1.674153 -0.479087 -0.445000  0.359257       2.0    2.0
# 10  0.841916  0.0 -1.796478  0.481288  0.710763 -0.320583       2.0    1.0
# 11 -1.546098  0.0  1.951804 -0.479087 -0.445000 -0.130140       2.0    1.0
#
#     Ticket  cluster
# 1    816.0        0
# 3     65.0        3
# 6    109.0       10
# 10   839.0        8
# 11    50.0       10

# %%
X_train.shape
# Out:
# (295, 10)

# %%
na_cabin_df = age_df[cabin_con].copy()

X_test = na_cabin_df[feature_cols]
y_test = na_cabin_df["Cabin"]

# %%
X_test.head(5)
# Out:
#      Pclass  Sex       Age     SibSp     Parch      Fare  Embarked  Title  \
# 0  0.841916  1.0 -0.547050  0.481288 -0.445000 -0.503291       2.0    2.0
# 2  0.841916  0.0 -0.269400 -0.479087 -0.445000 -0.490240       2.0    1.0
# 4  0.841916  1.0  0.355314 -0.479087 -0.445000 -0.487824       2.0    2.0
# 5  0.841916  1.0 -0.230127 -0.479087 -0.445000 -0.479930       1.0    2.0
# 7  0.841916  1.0 -1.935303  2.402037  0.710763 -0.235995       2.0    0.0
#
#    Ticket  cluster
# 0   720.0        1
# 2   914.0        1
# 4   649.0        1
# 5   373.0        6
# 7   541.0        4

# %%
merged_df.groupby(merged_df.Cabin.isna())["Pclass"].value_counts()
# Out:
# Cabin  Pclass
# False  1         256
#        2          23
#        3          16
# True   3         693
#        2         254
#        1          67
# Name: count, dtype: int64

# %%
deck_map = {"A":"ABC", "B":"ABC", "C":"ABC", "T":"ABC",
            "D":"DE",  "E":"DE",
            "F":"FG",  "G":"FG",
            "Unknown":"Unknown"}
age_df["Deck"] = merged_df["Cabin_Title"].map(deck_map).values

# %%
age_df["TicketGroup"] = merged_df.groupby("Ticket")["Ticket"].transform("count").values

# %%
age_df    = age_df.reset_index(drop=True)
merged_df = merged_df.reset_index(drop=True)

age_df["FamilySize"]  = (merged_df["SibSp"] + merged_df["Parch"] + 1).values
age_df["IsAlone"]     = (age_df["FamilySize"] == 1).astype(int)
age_df["FarePerHead"] = merged_df["Fare"].fillna(merged_df["Fare"].median()).values / age_df["TicketGroup"]

model_df = pd.get_dummies(age_df, columns=["Deck", "Title", "Embarked", "cluster"])

# %%
age_df["IsAlone"].sum()
# Out:
# np.int64(790)

# %%
drop_cols = ["PassengerId", "Name", "Ticket", "Cabin", "Cabin_Title", "Survived", "train_col"]
feature_cols = [c for c in model_df.columns if c not in drop_cols]

train = model_df[model_df.train_col == 1]
test  = model_df[model_df.train_col == 0]

X = train[feature_cols]
y = train["Survived"].astype(int)

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

rf = RandomForestClassifier(n_estimators=500, random_state=0)
scores = cross_val_score(rf, X, y, cv=5)
print(scores.round(4), scores.mean().round(4))
# Out:
# [0.838  0.7809 0.8596 0.764  0.8146] 0.8114
