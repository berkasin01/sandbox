# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
age_df = merged_df.copy()

# %%
age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df.dropna(subset=["Fare","Embarked"],inplace=True)

# %%
age_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# train_col        0
# dtype: int64

# %%
get_name = age_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
age_df["Title"] = get_title

# %%
age_df["Title"].value_counts()
# Out:
# Title
# Mr              756
# Miss            259
# Mrs             196
# Master           61
# Rev               8
# Dr                8
# Col               4
# Ms                2
# Major             2
# Mlle              2
# Don               1
# Mme               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: count, dtype: int64

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

age_df["Title"] = age_df["Title"].str.strip().map(title_map)

# %%
age_df.head(5)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Embarked  train_col  \
# 0    male  22.0      1      0         A/5 21171   7.2500        S          1
# 1  female  38.0      1      0          PC 17599  71.2833        C          1
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250        S          1
# 3  female  35.0      1      0            113803  53.1000        S          1
# 4    male  35.0      0      0            373450   8.0500        S          1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked', 'train_col', 'Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

age_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 413         1305       3                                 Spector, Mr. Woolf
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
#      Sex   Age  SibSp  Parch  Ticket      Fare  Embarked  train_col  Title
# 0    1.0  22.0      1      0   718.0    7.2500       2.0          1    2.0
# 1    0.0  38.0      1      0   814.0   71.2833       0.0          1    3.0
# 2    0.0  26.0      0      0   912.0    7.9250       2.0          1    1.0
# 3    0.0  35.0      1      0    64.0   53.1000       2.0          1    3.0
# 4    1.0  35.0      0      0   647.0    8.0500       2.0          1    2.0
# ..   ...   ...    ...    ...     ...       ...       ...        ...    ...
# 413  1.0   NaN      0      0   709.0    8.0500       2.0          0    2.0
# 414  0.0  39.0      0      0   832.0  108.9000       0.0          0    4.0
# 415  1.0  38.5      0      0   870.0    7.2500       2.0          0    2.0
# 416  1.0   NaN      0      0   578.0    8.0500       2.0          0    2.0
# 417  1.0   NaN      1      1   261.0   22.3583       0.0          0    0.0
#
# [1306 rows x 12 columns]

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Ticket","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.6488853669200084, inertia:22654459.710155495
# n_clusters:3, sil_score:0.6066103087131817, inertia:9939029.467074938
# n_clusters:4, sil_score:0.5864469748255469, inertia:5566725.133576351
# n_clusters:5, sil_score:0.5831154774944717, inertia:3494931.793433569
# n_clusters:6, sil_score:0.5592171166270921, inertia:2609684.6931088255
# n_clusters:7, sil_score:0.5430549504437819, inertia:1891433.3785787113
# n_clusters:8, sil_score:0.5450140217778433, inertia:1456716.4579681105
# n_clusters:9, sil_score:0.5420954512475943, inertia:1264281.9796660377
# n_clusters:10, sil_score:0.5198936795088284, inertia:976343.3335388538
# n_clusters:11, sil_score:0.536478316970032, inertia:788510.8636273505
# n_clusters:12, sil_score:0.5391869619642465, inertia:648536.3198997898
# n_clusters:13, sil_score:0.5380662688496751, inertia:559160.2184671756
# n_clusters:14, sil_score:0.537743762256973, inertia:469425.5527897269
# n_clusters:15, sil_score:0.5427727550499828, inertia:395044.0643641056
# n_clusters:16, sil_score:0.5308381765304455, inertia:382096.89672637434
# n_clusters:17, sil_score:0.5311758306102462, inertia:327781.16801758076
# n_clusters:18, sil_score:0.5226216468157363, inertia:290488.5714570468
# n_clusters:19, sil_score:0.5208469635314689, inertia:264693.60648739466
# n_clusters:20, sil_score:0.5205517391827702, inertia:235750.25640739407
# n_clusters:21, sil_score:0.5207833294678809, inertia:226624.01577421947
# n_clusters:22, sil_score:0.5243714034756539, inertia:196070.19731823087
# n_clusters:23, sil_score:0.5245267416080299, inertia:176204.058594494
# n_clusters:24, sil_score:0.5210349094849133, inertia:165648.2121877829
# n_clusters:25, sil_score:0.5235567919333833, inertia:151289.2000843986
# n_clusters:26, sil_score:0.507711602225134, inertia:146821.34961864565
# n_clusters:27, sil_score:0.5190598162615929, inertia:127590.60279446561
# n_clusters:28, sil_score:0.5143362467222765, inertia:128061.55073928492
# n_clusters:29, sil_score:0.5221079073998998, inertia:110718.32515318002
# n_clusters:30, sil_score:0.5231178274986187, inertia:102196.41551675646
# n_clusters:31, sil_score:0.516082332101982, inertia:97139.33565268504
# n_clusters:32, sil_score:0.5175201768029609, inertia:93184.86563017295
# n_clusters:33, sil_score:0.5156201542066927, inertia:88463.52638923125
# n_clusters:34, sil_score:0.5166707473313726, inertia:80298.48061881603
# n_clusters:35, sil_score:0.5102000062606656, inertia:78625.09055257867
# n_clusters:36, sil_score:0.5134496967431588, inertia:73559.15406114931
# n_clusters:37, sil_score:0.510284201532763, inertia:70400.06770554346
# n_clusters:38, sil_score:0.509295132418025, inertia:67245.49393852991
# n_clusters:39, sil_score:0.5064465272992141, inertia:64268.52294559418

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(3,7,1):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        25.822271  12.312289  151.592451    317
# 1        30.391653  14.630155  214.041424    363
# 2        32.719945  14.998515  224.955456    363
#               mean        std         var  count
# cluster
# 0        35.324733  14.366088  206.384476    281
# 1        30.341419  14.161219  200.540136    310
# 2        26.294439  13.414795  179.956734    223
# 3        25.761659  13.280062  176.360046    229
#               mean        std         var  count
# cluster
# 0        30.631765  14.556922  211.903968    272
# 1        26.431159  13.767160  189.534695    207
# 2        28.741986  13.850079  191.824686    146
# 3        25.451564  12.331416  152.063814    179
# 4        35.731883  14.379377  206.766493    239
#               mean        std         var  count
# cluster
# 0        30.851518  14.688257  215.744889    257
# 1        27.602192  14.065748  197.845272    146
# 2        24.865636  11.995650  143.895610    165
# 3        26.733537  13.034840  169.907065    147
# 4        36.697100  14.414567  207.779732    200
# 5        29.408828  14.159776  200.499251    128

# %%
k_best = KMeans(n_clusters=5)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      27.869177
# 1      30.760290
# 2      30.760290
# 3      35.687426
# 4      27.869177
#          ...
# 413    27.869177
# 414    30.760290
# 415    30.760290
# 416    27.869177
# 417    26.865578
# Name: Age, Length: 1306, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# train_col      0
# Title          0
# cluster        0
# dtype: int64
