# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.3212054666021956, inertia:4530.965307230348
# n_clusters:3, sil_score:0.33606918844467565, inertia:3476.6307744031033
# n_clusters:4, sil_score:0.35405704072169397, inertia:2946.97988899242
# n_clusters:5, sil_score:0.3204940829155212, inertia:2705.0972804671665
# n_clusters:6, sil_score:0.3402246792702572, inertia:2230.519719886931
# n_clusters:7, sil_score:0.3656768825217691, inertia:2046.194380648571
# n_clusters:8, sil_score:0.3470088875708004, inertia:2039.0906081267299
# n_clusters:9, sil_score:0.42170789582947266, inertia:1599.8682487398878
# n_clusters:10, sil_score:0.4328417830513266, inertia:1481.8337683243808
# n_clusters:11, sil_score:0.42053480234411833, inertia:1492.1936777661138
# n_clusters:12, sil_score:0.3964777328953461, inertia:1474.584863933733
# n_clusters:13, sil_score:0.4656223336155633, inertia:1261.2346821578556
# n_clusters:14, sil_score:0.47271938332827806, inertia:1190.5764424965523
# n_clusters:15, sil_score:0.47643957733240283, inertia:1156.553151667074
# n_clusters:16, sil_score:0.48712543468216535, inertia:1046.1348324743842
# n_clusters:17, sil_score:0.47956457027722604, inertia:1065.4180825247631
# n_clusters:18, sil_score:0.48564707412812186, inertia:1005.1453647840889
# n_clusters:19, sil_score:0.5140690920607924, inertia:908.0626988207973
# n_clusters:20, sil_score:0.5183895950239197, inertia:908.0713611188912
# n_clusters:21, sil_score:0.5200975214547292, inertia:866.4350821911445
# n_clusters:22, sil_score:0.5554642223354613, inertia:811.1476750972719
# n_clusters:23, sil_score:0.5140038762210865, inertia:850.270806016162
# n_clusters:24, sil_score:0.5408633337801578, inertia:793.2005787455179
# n_clusters:25, sil_score:0.5718372644903054, inertia:736.8191084600351
# n_clusters:26, sil_score:0.5724023735367342, inertia:721.931155565034
# n_clusters:27, sil_score:0.569948358978819, inertia:680.286077614553
# n_clusters:28, sil_score:0.6013813811683566, inertia:693.3791846399365
# n_clusters:29, sil_score:0.5823539293890343, inertia:651.0652793070843
# n_clusters:30, sil_score:0.590174807885834, inertia:600.4143978505329
# n_clusters:31, sil_score:0.599164739720548, inertia:587.7425525893041
# n_clusters:32, sil_score:0.6292414842053358, inertia:546.2258097568416
# n_clusters:33, sil_score:0.5935450479413094, inertia:595.2250547402723
# n_clusters:34, sil_score:0.6152969330030847, inertia:560.6518983977858
# n_clusters:35, sil_score:0.6198162078397779, inertia:525.3736638846653
# n_clusters:36, sil_score:0.6434462029737653, inertia:509.9094315127786
# n_clusters:37, sil_score:0.6359638707084494, inertia:484.82461453733754
# n_clusters:38, sil_score:0.634585988102988, inertia:481.4915649987222
# n_clusters:39, sil_score:0.6393964038985176, inertia:484.844221812913

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        17.868571  15.750739  248.085766    168
# 1        32.179670  12.937256  167.372603    878
#               mean        std         var  count
# cluster
# 0        26.622259  10.601736  112.396812    456
# 1        16.320299  15.535711  241.358328    134
# 2        37.125000  13.296564  176.798626    456
#               mean        std         var  count
# cluster
# 0        23.704200  12.035990  144.865067    100
# 1        31.826321  12.576815  158.176285    666
# 2        37.858621  13.288427  176.582304    145
# 3        16.292000  15.368064  236.177382    135
#               mean        std         var  count
# cluster
# 0        10.625000   8.897429   79.164244     44
# 1        35.279104  13.888419  192.888185    335
# 2        26.014096  16.561476  274.282476     83
# 3        35.679012  14.544894  211.553936    162
# 4        26.138626  11.330016  128.369254    422
#               mean        std         var  count
# cluster
# 0        34.757812  13.890463  192.944965    192
# 1        27.867403   9.887824   97.769073    362
# 2        10.654762   8.891273   79.054733     42
# 3        36.996564  13.308993  177.129298    291
# 4        18.655274  14.955370  223.663104    146
# 5        42.846154   9.281219   86.141026     13
#               mean        std         var  count
# cluster
# 0        17.731888  11.275581  127.138725    143
# 1        28.863793  10.134710  102.712352    290
# 2        35.369565  13.426662  180.275244    184
# 3        14.500000        NaN         NaN      1
# 4        28.675455  16.092468  258.967517     77
# 5        10.857143   8.703448   75.750000     49
# 6        36.711921  13.385225  179.164243    302
#               mean        std         var  count
# cluster
# 0        16.823313  11.356615  128.972714    166
# 1        35.574074  13.366970  178.675883    216
# 2        11.000000   8.673205   75.224490     50
# 3        36.535256  13.721670  188.284233    156
# 4        37.145833  10.544212  111.180408     48
# 5        28.410169   9.851511   97.052277    295
# 6        14.500000        NaN         NaN      1
# 7        38.166667  13.137070  172.582596    114
#               mean        std         var  count
# cluster
# 0        36.708333  10.895457  118.710993     48
# 1        28.313253   9.654947   93.218009    249
# 2        40.540816  13.585103  184.555018     98
# 3        11.033333   8.808828   77.595455     45
# 4        38.176991  13.195122  174.111252    113
# 5        17.630282  11.423634  130.499420    142
# 6        35.585714  13.138835  172.628982    210
# 7        23.282879  14.475592  209.542775     66
# 8        28.626667  11.967606  143.223604     75
#               mean        std         var  count
# cluster
# 0        27.624214   9.755504   95.169853    318
# 1        34.856757  13.527740  182.999750    185
# 2        10.974396  11.411086  130.212894     91
# 3        33.970149  11.700777  136.908186     67
# 4        28.290000  11.356959  128.980510     50
# 5        38.285714  13.222577  174.836551    112
# 6        37.250000  11.199244  125.423077     40
# 7        14.500000        NaN         NaN      1
# 8        36.312057  13.915246  193.634068    141
# 9        10.268293   8.479459   71.901220     41
#               mean        std         var  count
# cluster
# 0        35.030387  13.525405  182.936572    181
# 1        17.831556   9.420305   88.742150     45
# 2         9.687500   7.931346   62.906250     40
# 3        40.500000  13.586602  184.595745     48
# 4        27.842857   9.686777   93.833641    280
# 5        11.321875  11.346036  128.732537     80
# 6        37.472000  12.713706  161.638323    125
# 7        36.806818  13.525292  182.933516     88
# 8        41.333333  12.187425  148.533333     21
# 9        28.595588  10.521924  110.710876     68
# 10       33.485714  11.711190  137.151967     70
#               mean        std         var  count
# cluster
# 0        37.576923  12.714434  161.656828    130
# 1        28.334471   9.842113   96.867198    293
# 2        36.231959  13.339928  177.953688    194
# 3        19.051892  16.143662  260.617827     37
# 4        11.785211  11.741491  137.862617     71
# 5        39.238739  13.583554  184.512940    111
# 6        30.780000  10.702753  114.548919     75
# 7        14.500000        NaN         NaN      1
# 8              NaN        NaN         NaN      0
# 9        21.673611   7.240418   52.423660     72
# 10       40.350000  11.617931  134.976316     20
# 11       10.761905   8.965543   80.380952     42
#               mean        std         var  count
# cluster
# 0        29.517045   9.867353   97.364649     88
# 1        40.893617  13.454002  181.010176     47
# 2        35.559113  13.434714  180.491538    203
# 3         9.050000   8.396807   70.506368     75
# 4        10.268293   8.479459   71.901220     41
# 5        17.260500   9.792798   95.898897     40
# 6        32.914894   9.929271   98.590426     47
# 7        26.212500   8.812788   77.665224     40
# 8        40.116279  13.447430  180.833379     86
# 9        28.206642  10.235817  104.771956    271
# 10       36.877660  12.718348  161.756377     94
# 11       42.846154   9.281219   86.141026     13
# 12       14.500000        NaN         NaN      1
#               mean        std         var  count
# cluster
# 0        21.500000   7.457084   55.608108     75
# 1        38.083333  13.221425  174.806075    108
# 2        40.893617  13.454002  181.010176     47
# 3        10.268293   8.479459   71.901220     41
# 4        28.534979   9.900946   98.028730    243
# 5        36.312057  13.915246  193.634068    141
# 6        28.333333  10.841601  117.540323     63
# 7        42.846154   9.281219   86.141026     13
# 8        37.382353  12.763566  162.908613     85
# 9         5.768868   5.825643   33.938122     53
# 10       26.982581  14.658208  214.863075     62
# 11       28.255102  11.471942  131.605442     49
# 12       34.400000  11.609264  134.775000     65
# 13       14.500000        NaN         NaN      1
#               mean        std         var  count
# cluster
# 0        39.137255  13.378007  178.971074    102
# 1        28.313253   9.654947   93.218009    249
# 2         9.421053   8.280983   68.574680     38
# 3        39.654255  13.624383  185.623799     94
# 4        26.654930  11.333450  128.447082     71
# 5         6.658548   6.379936   40.703586     62
# 6        41.083333   7.064100   49.901515     12
# 7        33.032258   9.917943   98.365591     31
# 8        24.660920   7.748028   60.031943     87
# 9        40.893617  13.454002  181.010176     47
# 10       14.500000        NaN         NaN      1
# 11       23.395429  17.180341  295.164120     35
# 12       39.754545  13.510241  182.526599     55
# 13       32.430328  12.325361  151.914527    122
# 14       31.550000   8.908941   79.369231     40
#               mean        std         var  count
# cluster
# 0        21.902174  13.689156  187.392995     46
# 1        38.245455  13.331474  177.728190    110
# 2        28.702000  10.145933  102.939956    250
# 3        36.166667  11.089892  122.985714     36
# 4        36.530055  13.363902  178.593872    183
# 5        30.205882  18.998851  360.956328     34
# 6        26.920000   8.393000   70.442449     50
# 7        40.391304  13.149530  172.910145     46
# 8        14.500000        NaN         NaN      1
# 9         8.632979   8.760494   76.746252     47
# 10       39.888889   1.452966    2.111111      9
# 11       20.563077   8.250459   68.070079     78
# 12       13.818182   9.084976   82.536797     22
# 13        5.900000   3.625930   13.147368     20
# 14       37.815385  12.550700  157.520072     65
# 15       28.255102  11.471942  131.605442     49
#               mean        std         var  count
# cluster
# 0        38.956522  13.172425  173.512788     69
# 1        29.153846   9.483494   89.936652     52
# 2        30.187500  12.514513  156.613032     48
# 3        33.032258  10.070531  101.415591     31
# 4        35.888889  13.165108  173.320079    198
# 5        38.620536  12.996057  168.897502    112
# 6        28.603376   9.922842   98.462785    237
# 7        22.750000   9.806118   96.159946     94
# 8        14.500000        NaN         NaN      1
# 9        24.952381  19.729359  389.247619     21
# 10       11.245556   8.398971   70.542708     18
# 11        8.837838   7.562751   57.195195     37
# 12       42.846154   9.281219   86.141026     13
# 13        4.397273   4.018083   16.144992     22
# 14       45.500000  11.250778  126.580000     26
# 15       28.291667  11.399768  129.954710     24
# 16       15.023488   9.791150   95.866618     43
#               mean        std         var  count
# cluster
# 0        29.411111  11.028521  121.628283     45
# 1        29.721429   9.875176   97.519099     70
# 2        26.673913  11.244877  126.447251     69
# 3        28.559908   9.845619   96.936209    217
# 4        34.236842  10.382376  107.793741     38
# 5        10.268293   8.479459   71.901220     41
# 6        39.456897  13.806077  190.607759     58
# 7        14.500000        NaN         NaN      1
# 8        22.421875   7.267136   52.811260     64
# 9        42.404110  12.689852  161.032344     73
# 10             NaN        NaN         NaN      0
# 11       40.893617  13.454002  181.010176     47
# 12        4.652286   4.117816   16.956406     35
# 13       38.302752  13.379437  179.009344    109
# 14       42.846154   9.281219   86.141026     13
# 15       32.687500   9.949672   98.995968     32
# 16       11.200909   9.228564   85.166385     44
# 17       32.250000  12.838069  164.816011     90
#               mean        std         var  count
# cluster
# 0        39.985294  13.453897  181.007353     34
# 1        28.559908   9.845619   96.936209    217
# 2         5.900000   3.625930   13.147368     20
# 3        42.846154   9.281219   86.141026     13
# 4        28.253846  10.585634  112.055649     65
# 5        18.777778   9.066575   82.202778     36
# 6        40.583333  14.104457  198.935714     36
# 7        37.552239  12.592727  158.576775     67
# 8         4.712258   4.103223   16.836438     31
# 9        35.787565  13.263906  175.931199    193
# 10       18.333333   5.609516   31.466667      6
# 11       38.108696  13.395470  179.438605     92
# 12       13.187500  10.393708  108.029167     16
# 13       32.075758   9.096807   82.751894     33
# 14       12.596562   9.690912   93.913772     32
# 15       22.134615  10.479935  109.829046     78
# 16       26.569767   7.746413   60.006921     43
# 17       14.500000        NaN         NaN      1
# 18       39.666667  13.873686  192.479167     33

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.462151
# 1      40.893617
# 2      24.072222
# 3      38.980000
# 4      28.462151
#          ...
# 413    28.462151
# 414    40.893617
# 415    28.462151
# 416    28.462151
# 417     8.438861
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64
