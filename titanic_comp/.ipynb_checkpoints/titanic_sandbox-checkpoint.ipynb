# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.43832544504869064, inertia:4240.733494283764
# n_clusters:3, sil_score:0.33562600376482493, inertia:3474.639412600287
# n_clusters:4, sil_score:0.28852745143172515, inertia:3022.550160816236
# n_clusters:5, sil_score:0.31161830251348, inertia:2715.15475295836
# n_clusters:6, sil_score:0.352356275879883, inertia:2184.331432647544
# n_clusters:7, sil_score:0.33503459657833995, inertia:2208.7155959624606
# n_clusters:8, sil_score:0.3462104553305542, inertia:1953.3762288911903
# n_clusters:9, sil_score:0.37847377660177106, inertia:1724.1237642165634
# n_clusters:10, sil_score:0.37534478725671716, inertia:1582.5663270296784
# n_clusters:11, sil_score:0.39272439666059566, inertia:1607.6558582161576
# n_clusters:12, sil_score:0.45667034873720985, inertia:1313.1617036914888
# n_clusters:13, sil_score:0.4580844667316459, inertia:1219.8955569478198
# n_clusters:14, sil_score:0.42081066959129737, inertia:1295.4765870667466
# n_clusters:15, sil_score:0.4776447776345808, inertia:1211.539636564893
# n_clusters:16, sil_score:0.47052946787678324, inertia:1046.4802554788812
# n_clusters:17, sil_score:0.4772348648296996, inertia:1014.3668514815895
# n_clusters:18, sil_score:0.451049882842926, inertia:1207.2443834266103
# n_clusters:19, sil_score:0.4899039983837054, inertia:969.9507262302997
# n_clusters:20, sil_score:0.48999765787025185, inertia:899.0278412234238
# n_clusters:21, sil_score:0.5030757990455105, inertia:911.0094749158287
# n_clusters:22, sil_score:0.5334976517776339, inertia:799.7328462551802
# n_clusters:23, sil_score:0.572781812977266, inertia:790.0358825964995
# n_clusters:24, sil_score:0.5932688934331525, inertia:759.3189780772475
# n_clusters:25, sil_score:0.570475513305059, inertia:743.7991350206229
# n_clusters:26, sil_score:0.5589856818142119, inertia:725.3708120940422
# n_clusters:27, sil_score:0.5935475477182722, inertia:671.8283041040987
# n_clusters:28, sil_score:0.5863903343161734, inertia:646.7967194521286
# n_clusters:29, sil_score:0.60332740926202, inertia:613.8194991447401
# n_clusters:30, sil_score:0.609085489497093, inertia:591.595565861292
# n_clusters:31, sil_score:0.6015733363865188, inertia:596.6535555889162
# n_clusters:32, sil_score:0.6331744932141536, inertia:564.3236400689404
# n_clusters:33, sil_score:0.6126562423771614, inertia:577.6849543581703
# n_clusters:34, sil_score:0.6136238775748581, inertia:550.1689985971208
# n_clusters:35, sil_score:0.623770795627757, inertia:526.9771218566069
# n_clusters:36, sil_score:0.6288931391339608, inertia:505.0418725426945
# n_clusters:37, sil_score:0.6108726338075925, inertia:518.1137404932241
# n_clusters:38, sil_score:0.6322145553003814, inertia:485.7678789326236
# n_clusters:39, sil_score:0.6412262101930265, inertia:471.2539246725622

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        31.211846  13.587698  184.625549    937
# 1        18.441927  16.206276  262.643397    109
#               mean        std         var  count
# cluster
# 0        32.601714  14.374327  206.621277    245
# 1        16.158841  15.567588  242.349803    138
# 2        31.732021  12.498321  156.208017    663
#               mean        std         var  count
# cluster
# 0        29.102601  12.928136  167.136692    592
# 1        37.471818  14.350567  205.938777    198
# 2        14.993692  14.021982  196.615980     65
# 3        29.491728  14.320350  205.072412    191
#               mean        std         var  count
# cluster
# 0        33.564282  14.891839  221.766869    376
# 1        10.968085   8.801188   77.460916     47
# 2        26.424350  11.201133  125.465391    423
# 3        34.086111  15.412175  237.535141    180
# 4        40.350000  11.617931  134.976316     20
#               mean        std         var  count
# cluster
# 0        36.327476  13.282095  176.414050    313
# 1        16.907985  14.483604  209.774779    134
# 2        41.631579  10.382734  107.801170     19
# 3        27.729275   9.976395   99.528465    386
# 4        10.848837   8.876490   78.792082     43
# 5        37.473510  13.250885  175.585960    151
#               mean        std         var  count
# cluster
# 0        29.344262  10.424237  108.664720    366
# 1        11.184783   8.770759   76.926208     46
# 2        16.776154  11.394433  129.833107    169
# 3        37.769784  13.923219  193.856037    139
# 4        28.675325  11.815402  139.603725     77
# 5        40.350000  11.617931  134.976316     20
# 6        38.868996  12.837133  164.791973    229
#               mean        std         var  count
# cluster
# 0        37.250000  11.199244  125.423077     40
# 1        38.166667  13.137070  172.582596    114
# 2        22.647360   9.069151   82.249492    125
# 3        28.571698  10.062426  101.252416    265
# 4        38.300725  13.118291  172.089562    138
# 5        12.260989  11.271626  127.049558     91
# 6         8.986842   7.516187   56.493065     38
# 7        35.189362  13.145036  172.791980    235
#               mean        std         var  count
# cluster
# 0        38.125000  13.242795  175.371622    112
# 1        28.313253   9.654947   93.218009    249
# 2        10.848837   8.876490   78.792082     43
# 3        35.574074  13.366970  178.675883    216
# 4        35.891304  14.096377  198.707836     92
# 5        24.657561  12.497252  156.181305     82
# 6        26.483580  16.461409  270.977971     81
# 7        19.307097  11.113112  123.501260    124
# 8        40.893617  13.454002  181.010176     47
#               mean        std         var  count
# cluster
# 0        27.385542  12.285557  150.934910     83
# 1        36.924000  13.388249  179.245205    250
# 2         8.758375   8.361099   69.907968     80
# 3        38.953488  13.249181  175.540789    129
# 4        35.782051  11.959235  143.023310     78
# 15             NaN        NaN         NaN      0
# 16       32.700000  15.432804  238.171429     15
# 17       33.176471   9.519424   90.619430     34
# 18       32.631818  12.385008  153.388428    110

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.462151
# 1      39.280000
# 2      24.072222
# 3      37.789474
# 4      28.462151
#          ...
# 413    28.462151
# 414    39.280000
# 415    28.462151
# 416    28.462151
# 417    25.011358
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str.split().str[0]

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str[0]

# %%
cabin_df.Cabin
# Out:
# 1      C
# 3      C
# 6      E
# 10     G
# 11     C
#       ..
# 404    D
# 405    D
# 407    C
# 411    C
# 414    C
# Name: Cabin, Length: 295, dtype: object

# %%
cabin_df["Cabin"].value_counts()
# Out:
# Cabin
# C    94
# B    65
# D    46
# E    41
# A    22
# F    21
# G     5
# T     1
# Name: count, dtype: int64

# %%
cabin_df.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0       1
# 3             4       1.0       1
# 6             7       0.0       1
# 10           11       1.0       3
# 11           12       1.0       1
#
#                                                  Name  Sex   Age     SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0  38.0  0.481288
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0  35.0  0.481288
# 6                             McCarthy, Mr. Timothy J  1.0  54.0 -0.479087
# 10                    Sandstrom, Miss. Marguerite Rut  0.0   4.0  0.481288
# 11                           Bonnell, Miss. Elizabeth  0.0  58.0 -0.479087
#
#        Parch  Ticket      Fare Cabin  Embarked  train_col  Title Cabin_Title  \
# 1  -0.445000   816.0  0.734744     C       0.0          1    3.0           C
# 3  -0.445000    65.0  0.383183     C       2.0          1    3.0           C
# 6  -0.445000   109.0  0.359257     E       2.0          1    2.0           E
# 10  0.710763   839.0 -0.320583     G       2.0          1    1.0           G
# 11 -0.445000    50.0 -0.130140     C       2.0          1    1.0           C
#
#     cluster
# 1         9
# 3        10
# 6         4
# 10        7
# 11        4
