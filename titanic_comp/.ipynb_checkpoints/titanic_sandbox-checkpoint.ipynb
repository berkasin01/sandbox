# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.27683033864521356, inertia:4591.456292495195
# n_clusters:3, sil_score:0.325281891721864, inertia:3558.7601941373205
# n_clusters:4, sil_score:0.28810089204288203, inertia:3018.2690154585634
# n_clusters:5, sil_score:0.3286416054962568, inertia:2822.1907503820066
# n_clusters:6, sil_score:0.33086485208751826, inertia:2267.96086448449
# n_clusters:7, sil_score:0.3480391416548941, inertia:2013.4463447246808
# n_clusters:8, sil_score:0.361658543839885, inertia:1903.4758251839019
# n_clusters:9, sil_score:0.3896418764686331, inertia:1672.553196127878
# n_clusters:10, sil_score:0.3748857355448076, inertia:1652.4256859994593
# n_clusters:11, sil_score:0.419679058421059, inertia:1500.7164555129418
# n_clusters:12, sil_score:0.43616938964742946, inertia:1354.3293947632214
# n_clusters:13, sil_score:0.4571279217474123, inertia:1229.7428523020294
# n_clusters:14, sil_score:0.43181803227027893, inertia:1278.3911459635597
# n_clusters:15, sil_score:0.47157620392482086, inertia:1115.4459045825474
# n_clusters:16, sil_score:0.4818996365397249, inertia:1067.4564458351456
# n_clusters:17, sil_score:0.500975138011618, inertia:999.5500975347643
# n_clusters:18, sil_score:0.503680145773055, inertia:932.0396440428253
# n_clusters:19, sil_score:0.511732022587388, inertia:927.3344931919638
# n_clusters:20, sil_score:0.5127049701328316, inertia:910.980922578706
# n_clusters:21, sil_score:0.5294620893152789, inertia:876.4004524815042
# n_clusters:22, sil_score:0.5543973109433508, inertia:826.3719944107909
# n_clusters:23, sil_score:0.556081855949094, inertia:804.3108690489922
# n_clusters:24, sil_score:0.5693999197182513, inertia:768.9144510026765
# n_clusters:25, sil_score:0.5756369413942239, inertia:741.9044222017319
# n_clusters:26, sil_score:0.5568851815110133, inertia:723.3600303010812
# n_clusters:27, sil_score:0.5695421024844851, inertia:683.9525554419165
# n_clusters:28, sil_score:0.61119795136843, inertia:665.9550791960199
# n_clusters:29, sil_score:0.5838935647380091, inertia:635.0877604931198
# n_clusters:30, sil_score:0.5975881042648914, inertia:611.4129171130669
# n_clusters:31, sil_score:0.6198288687653484, inertia:593.7171495638418
# n_clusters:32, sil_score:0.621069664958157, inertia:576.2587671298219
# n_clusters:33, sil_score:0.6276167547928951, inertia:574.2188600908331
# n_clusters:34, sil_score:0.6228910021021506, inertia:540.2584907350812
# n_clusters:35, sil_score:0.619027990032883, inertia:517.4143320288875
# n_clusters:36, sil_score:0.6197559571933702, inertia:515.3613726245899
# n_clusters:37, sil_score:0.6511852556410573, inertia:492.5100795020512
# n_clusters:38, sil_score:0.6427369030933876, inertia:491.48481117396744
# n_clusters:39, sil_score:0.6610448752512559, inertia:461.27524436982765

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        36.704905  13.776810  189.800481    473
# 1        24.248255  12.354471  152.632954    573
#               mean        std         var  count
# cluster
# 0        28.631582  12.773736  163.168335    689
# 1        37.038889  14.343935  205.748482    270
# 2        17.563333  15.767994  248.629625     87
#               mean        std         var  count
# cluster
# 0        34.765625  13.629724  185.769388    192
# 1        19.048927  12.115269  146.779743    177
# 2        20.135978  16.289237  265.339237     92
# 3        33.088034  12.519418  156.735815    585
#               mean        std         var  count
# cluster
# 0        37.497658  13.214864  174.632624    427
# 1        18.626149  15.497820  240.182414    148
# 2        27.592857   9.743779   94.941238    420
# 3         8.986842   7.516187   56.493065     38
# 4        42.846154   9.281219   86.141026     13
#               mean        std         var  count
# cluster
# 0        11.184783   8.770759   76.926208     46
# 1        28.455298  10.027975  100.560287    302
# 2        37.774194  13.023994  169.624412    186
# 3        19.103684  12.437489  154.691121    209
# 4        36.386525  13.285045  176.492416    282
# 5        41.333333  12.187425  148.533333     21
#               mean        std         var  count
# cluster
# 0        36.882155  13.280164  176.362755    297
# 1        28.097305   9.899053   97.991254    334
# 2        37.250000  11.199244  125.423077     40
# 3        10.848837   8.876490   78.792082     43
# 4        36.301282  13.977018  195.357031    156
# 5        25.565778  12.015202  144.365079     90
# 6        11.590116  11.213023  125.731886     86
#               mean        std         var  count
# cluster
# 0        36.188776  13.038507  170.002656     98
# 1        34.630165  13.380584  179.040041    242
# 2        18.741443  16.950456  287.317971     97
# 3        27.106100   9.797616   95.993283    300
# 4         8.986842   7.516187   56.493065     38
# 5        24.027191  11.917484  142.026427     89
# 9        37.815385  12.550700  157.520072     65
# 10       31.710526   8.784685   77.170697     38
# 11       17.994667  12.569053  157.981102     30
# 12       34.453125  11.693072  136.727927     64
# 13       28.255102  11.471942  131.605442     49
# 14       34.758621  17.095645  292.261084     29
# 15       13.280000   9.697594   94.043333     25
# 16        8.078889   9.461126   89.512905     18
# 17       14.500000        NaN         NaN      1
#               mean        std         var  count
# cluster
# 0        28.446809   9.705621   94.199082    235
# 1        40.311111  13.286737  176.537374     45
# 2        36.075758   9.775704   95.564394     33
# 3        22.134615  10.479935  109.829046     78
# 4        39.654255  13.624383  185.623799     94
# 5         8.277778   6.847778   46.892063     36
# 6        28.317460  10.824964  117.179852     63
# 7        27.914286   9.678270   93.668908     35
# 8        33.032258   9.917943   98.365591     31
# 9        14.500000        NaN         NaN      1
# 10       32.631818  12.385008  153.388428    110
# 11        5.463438   4.836486   23.391597     32
# 12       31.541667  10.676993  113.998188     24
# 13       40.348837  13.337931  177.900410     86
# 14       32.380000  17.119239  293.068333     25
# 15       39.754545  13.510241  182.526599     55
# 16       12.385926   9.551218   91.225771     27
# 17       17.938824   9.164621   83.990277     34
# 18       41.500000   2.121320    4.500000      2

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      29.972527
# 1      40.290000
# 2      24.164773
# 3      39.769231
# 4      28.927966
#          ...
# 413    28.927966
# 414    40.290000
# 415    28.927966
# 416    28.927966
# 417    22.962059
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
known = age_df["Cabin_Title"] != "Unknown"

# %%
cluster_mode = age_df[known].groupby("cluster")["Cabin_Title"].agg(lambda s: s.mode()[0])

# %%
age_df["Has_Cabin"] = known.astype(int)
age_df["Deck_imputed"] = age_df["Cabin_Title"].where(known, age_df["cluster"].map(cluster_mode))
age_df["Deck_imputed"] = age_df["Deck_imputed"].fillna(age_df.loc[known, "Cabin_Title"].mode()[0])

# %%
age_df["Deck_imputed"]
# Out:
# 0      G
# 1      C
# 2      E
# 3      C
# 4      F
#       ..
# 413    F
# 414    C
# 415    F
# 416    F
# 417    D
# Name: Deck_imputed, Length: 1309, dtype: str
