# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.2730275158530257, inertia:4673.38325036969
# n_clusters:3, sil_score:0.30529520185437586, inertia:3479.495871286362
# n_clusters:4, sil_score:0.27477173712517694, inertia:3193.538221686629
# n_clusters:5, sil_score:0.3270150552216849, inertia:2586.2006439593065
# n_clusters:6, sil_score:0.3337837975258385, inertia:2260.3067715384755
# n_clusters:7, sil_score:0.3529109343726981, inertia:2080.63715366147
# n_clusters:8, sil_score:0.3556323367426779, inertia:1878.0991996334806
# n_clusters:9, sil_score:0.4227089085688838, inertia:1599.412440917198
# n_clusters:10, sil_score:0.4081721103928268, inertia:1527.7375390517798
# n_clusters:11, sil_score:0.4152099626774799, inertia:1465.3019365495184
# n_clusters:12, sil_score:0.445830344683864, inertia:1359.8457685198402
# n_clusters:13, sil_score:0.42607553862787545, inertia:1276.8981248508217
# n_clusters:14, sil_score:0.4481543645021468, inertia:1216.4706397936457
# n_clusters:15, sil_score:0.4544061468456385, inertia:1185.3606657142493
# n_clusters:16, sil_score:0.42222494940583505, inertia:1132.7723217986759
# n_clusters:17, sil_score:0.4994002862245896, inertia:1062.753808738916
# n_clusters:18, sil_score:0.4859677194462822, inertia:1074.3373443277317
# n_clusters:19, sil_score:0.4879227690831133, inertia:961.4388769043027
# n_clusters:20, sil_score:0.5427001492795966, inertia:911.6771839288604
# n_clusters:21, sil_score:0.5074527485346533, inertia:858.163110932874
# n_clusters:22, sil_score:0.5419608220766341, inertia:790.6725405455081
# n_clusters:23, sil_score:0.5576957826461038, inertia:807.5456396214048
# n_clusters:24, sil_score:0.5779815023264583, inertia:758.707655356561
# n_clusters:25, sil_score:0.5665055842269658, inertia:731.523195965313
# n_clusters:26, sil_score:0.5678620704597663, inertia:703.665462406859
# n_clusters:27, sil_score:0.5779383818916488, inertia:661.6568006420397
# n_clusters:28, sil_score:0.564135743212293, inertia:696.8557308207328
# n_clusters:29, sil_score:0.597820906110713, inertia:647.7350953322737
# n_clusters:30, sil_score:0.6104579950665223, inertia:627.0235313393835
# n_clusters:31, sil_score:0.6202057852562466, inertia:575.1864155314003
# n_clusters:32, sil_score:0.6052745714319339, inertia:565.1747687158022
# n_clusters:33, sil_score:0.6080822497180741, inertia:563.5536833740957
# n_clusters:34, sil_score:0.6167758050739738, inertia:538.9452826184809
# n_clusters:35, sil_score:0.623877728483912, inertia:528.2885658730332
# n_clusters:36, sil_score:0.6530582290211223, inertia:514.5970624232301
# n_clusters:37, sil_score:0.6457227478837034, inertia:480.87926013365046
# n_clusters:38, sil_score:0.6481150427676491, inertia:505.24638095086834
# n_clusters:39, sil_score:0.63239510672261, inertia:481.88740678645775

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        33.832372  16.154813  260.977992    253
# 1        28.620530  13.582936  184.496145    793
#               mean        std         var  count
# cluster
# 0        28.960844  12.826153  164.510202    711
# 1        36.240157  15.065499  226.969270    254
# 2        18.018642  16.047034  257.507294     81
#               mean        std         var  count
# cluster
# 0        33.807065  15.562719  242.198228    184
# 1        26.638019  11.021381  121.470849    419
# 2        18.225692  16.591059  275.263250     65
# 3        33.569233  14.852843  220.606943    378
#               mean        std         var  count
# cluster
# 0        27.062788  11.571956  133.910157    495
# 1        38.404977  13.499832  182.245475    221
# 2        10.625000   8.897429   79.164244     44
# 3        33.397026  14.717196  216.595844    195
# 4        26.287582  16.845261  283.762816     91
#               mean        std         var  count
# cluster
# 0        34.806604  14.377822  206.721765    106
# 1        36.554688  13.277281  176.286185    320
# 2        18.081375  16.138280  260.444075     80
# 3        28.918919  10.079944  101.605268    296
# 4        19.196522  11.205313  125.559028    184
# 5        38.833333  14.009884  196.276836     60
#               mean        std         var  count
# cluster
# 0        20.345652  10.580622  111.949567    115
# 1        35.645161  13.366776  178.670706    186
# 2        36.949664  13.308910  177.127087    298
# 3         8.986842   7.516187   56.493065     38
# 4        13.357949  11.467093  131.494232     78
# 5        28.871134  10.117997  102.373854    291
# 6        37.250000  11.199244  125.423077     40
#               mean        std         var  count
# cluster
# 0        38.066929  13.173651  173.545088    127
# 1        29.293447  10.709178  114.686500    351
# 2        10.848837   8.876490   78.792082     43
# 3        37.250000  11.199244  125.423077     40
# 4        35.699454  13.449533  180.889945    183
# 5        11.385222  11.480743  131.807466     90
# 6        23.204082   8.601677   73.988849     98
# 7        38.166667  13.137070  172.582596    114
#               mean        std         var  count
# cluster
# 0        24.072222   8.358055   69.857085     90
# 1        31.725290  14.249510  203.048534    155
# 2        29.293447  10.709178  114.686500    351
# 3        10.848837   8.876490   78.792082     43
# 4        39.947368  11.792058  139.052632     19
# 5        38.560484  12.928602  167.148751    124
# 6        37.527132  12.751273  162.594961    129
# 7        40.653061  13.486955  181.897959     49
# 8        12.206395  12.335980  152.176414     86
#               mean        std         var  count
# cluster
# 0        41.896154  13.691464  187.456187    130
# 1        28.854839  10.269108  105.454572    279
# 2        42.846154   9.281219   86.141026     13
# 3         8.986842   7.516187   56.493065     38
# 4        32.639344  10.032917  100.659426     61
# 5        22.418120   8.907991   79.352302    117
# 6        10.394578   9.479269   89.856540     83
# 7        32.675978  11.928793  142.296105    179
# 8        40.693878  13.885250  192.800170     49
# 9        36.500000  12.735081  162.182292     97
#               mean        std         var  count
# cluster
# 0        24.072222   8.358055   69.857085     90
# 1        29.150298  10.466458  109.546746    336
# 2        10.761905   8.965543   80.380952     42
# 3        38.662963  13.456096  181.066528    135
# 4        26.488235  13.012752  169.331705     85
# 5              NaN        NaN         NaN      0
# 6        38.709924  13.282863  176.434439    131
# 7        41.333333  12.187425  148.533333     21
# 8        14.500000        NaN         NaN      1
# 9        11.525233  11.219925  125.886710     86
# 10       37.201681  12.100273  146.416607    119
#               mean        std         var  count
# cluster
# 0        27.566667  12.347507  152.460920     30
# 1        36.212766  13.338856  177.925077    188
# 2        10.848837   8.876490   78.792082     43
# 3        42.846154   9.281219   86.141026     13
# 4        26.973333  11.142169  124.147928     75
# 5        38.862500  13.815918  190.879589     80
# 6         6.881000   6.752443   45.595490     70
# 7        28.313253   9.654947   93.218009    249
# 8        24.072222   8.358055   69.857085     90
# 9        37.325581  13.159825  173.180985     86
# 10       35.133333  11.334095  128.461712     75
# 11       40.893617  13.454002  181.010176     47
#               mean        std         var  count
# cluster
# 0        28.589552  10.601217  112.385798     67
# 1        31.909722  12.030650  144.736548    144
# 2        21.273103  15.922854  253.537265     29
# 3         9.551282   8.211669   67.431511     39
# 4        41.933333  10.010471  100.209524     15
# 5        11.659577  11.577481  134.038061     71
# 6        37.578313  12.855549  165.265134     83
# 7        36.102941  12.003904  144.093723     68
# 8        20.367750   8.398638   70.537116     80
# 9        39.062500  13.407976  179.773810     64
# 10       28.374486   9.672194   93.551330    243
# 11       40.265306  13.544334  183.448980     49
# 12       39.654255  13.624383  185.623799     94
#               mean        std         var  count
# cluster
# 0        24.770588   7.799784   60.836625     85
# 1        41.078947  13.672126  186.927018     76
# 2         9.055147   8.467190   71.693312     68
# 3        14.500000        NaN         NaN      1
# 4        28.728311  10.074057  101.486626    219
# 5        37.746988  13.200696  174.258375     83
# 6        42.846154   9.281219   86.141026     13
# 7        36.061798  13.469535  181.428363    178
# 8        13.014000  10.502258  110.297432     30
# 9        29.227941  11.925275  142.212193     68
# 10       30.067073   9.972110   99.442977     82
# 11       33.125000   9.818003   96.393182     56
# 12       40.826087  13.594614  184.813527     46
# 13       10.268293   8.479459   71.901220     41
#               mean        std         var  count
# cluster
# 0        28.728311  10.074057  101.486626    219
# 1        40.160920  13.375501  178.904036     87
# 2         9.258621   7.363788   54.225369     29
# 3        16.419189  12.308703  151.504169     37
# 4        37.275862  13.091307  171.382318     87
# 5        26.533333  11.300363  127.698198     75
# 6        42.846154   9.281219   86.141026     13
# 7        22.750000   9.806118   96.159946     94
# 8        11.900000   9.271091   85.953125     25
# 9        40.379121  13.222947  174.846337     91
# 10       32.250000  12.838069  164.816011     90
# 11       40.826087  13.594614  184.813527     46
# 12        4.714839   4.165303   17.349752     31
# 13       32.719512  10.015019  100.300610     41
# 14       29.944444   9.971835   99.437500     81
#               mean        std         var  count
# cluster
# 0         8.260152   8.211763   67.433051     66
# 1        32.508264  12.346387  152.433264    121
# 2        27.595238  11.046404  122.023041     63
# 3        15.166667   9.814216   96.318841     24
# 4        42.846154   9.281219   86.141026     13
# 5        28.313253   9.654947   93.218009    249
# 6        40.391304  13.149530  172.910145     46
# 7        32.243902   9.062369   82.126524     41
# 8        31.811321  10.972092  120.386792     53
# 9        24.005618   8.381356   70.247127     89
# 10       39.137255  13.378007  178.971074    102
# 11       22.241935  17.813207  317.310349     31
# 12       39.916667  13.582991  184.497642     54
# 13       14.500000        NaN         NaN      1
# 14        5.900000   3.625930   13.147368     20
# 15       42.404110  12.689852  161.032344     73
#               mean        std         var  count
# cluster
# 0        32.849138  12.472791  155.570521    116
# 1        22.089552   7.274866   52.923677     67
# 2         8.277778   6.847778   46.892063     36
# 3        37.793103  14.590553  212.884236     29
# 4        28.559908   9.845619   96.936209    217
# 5        39.805882  13.763974  189.446989     85
# 6        28.220339  10.694533  114.373027     59
# 7         4.506400   4.054793   16.441349     25
# 8        42.846154   9.281219   86.141026     13
# 9        36.672727  11.714275  137.224242     55
# 10       26.700000   7.593658   57.663636     45
# 11       14.500000        NaN         NaN      1
# 12       38.512821  13.395816  179.447885     78
# 13       42.404110  12.689852  161.032344     73
# 14       16.221800  12.313122  151.612970     50
# 15       30.842466  10.840663  117.519977     73
# 16       10.850833  10.362511  107.381625     24
#               mean        std         var  count
# cluster
# 0        28.559908   9.845619   96.936209    217
# 1        29.514925  10.007183  100.143713     67
# 2        39.410256  13.317416  177.353576     39
# 3        14.500000        NaN         NaN      1
# 4        24.164773   8.425032   70.981159     88
# 5        42.268657  13.584285  184.532791     67
# 6        15.803590  12.304552  151.402003     39
# 7        40.400000   2.118700    4.488889     10
# 8        38.030612  13.223010  174.848002     49
# 9        31.955556  10.027135  100.543434     45
# 10       36.337017  13.620846  185.527455    181
# 11       26.038462  11.863583  140.744591     65
# 12        8.837838   7.562751   57.195195     37
# 13       34.650000  11.954764  142.916379     30
# 14        3.979062   3.836457   14.718402     32
# 15       13.088235   9.320651   86.874540     17
# 16       39.967742  15.854513  251.365591     31
# 17       33.032258   9.917943   98.365591     31
#               mean        std         var  count
# cluster
# 0        28.500000  10.822528  117.127119     60
# 1        28.559908   9.845619   96.936209    217
# 2         8.625000   7.115408   50.629032     32
# 3        15.785714  14.820799  219.656085     28
# 4        40.379121  13.222947  174.846337     91
# 5        33.032258   9.917943   98.365591     31
# 6        42.846154   9.281219   86.141026     13
# 7        34.295775  11.019975  121.439839     71
# 8        32.631818  12.385008  153.388428    110
# 9        26.936739  14.008990  196.251805     46
# 10       40.386364  13.430642  180.382135     44
# 11       14.500000        NaN         NaN      1
# 12       39.754545  13.510241  182.526599     55
# 13       26.647727   7.673254   58.878832     44
# 14        4.712258   4.103223   16.836438     31
# 15       27.105263  18.955781  359.321637     19
# 16       45.195122  13.980736  195.460976     41
# 17       13.083333   9.701425   94.117647     18
# 18       23.521277   8.420697   70.908145     94

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.462151
# 1      40.826087
# 2      24.072222
# 3      39.029703
# 4      28.462151
#          ...
# 413    28.462151
# 414    40.826087
# 415    28.462151
# 416    28.462151
# 417     8.776463
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str.split().str[0]

# %%
cabin_df["Cabin"] = cabin_df["Cabin"].str[0]

# %%
cabin_df.Cabin
# Out:
# 1      C
# 3      C
# 6      E
# 10     G
# 11     C
#       ..
# 404    D
# 405    D
# 407    C
# 411    C
# 414    C
# Name: Cabin, Length: 295, dtype: object

# %%
cabin_df["Cabin"].value_counts()
# Out:
# Cabin
# C    94
# B    65
# D    46
# E    41
# A    22
# F    21
# G     5
# T     1
# Name: count, dtype: int64
