# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.22147400050453736, inertia:4661.642398118564
# n_clusters:3, sil_score:0.26581408586951094, inertia:3504.661919193067
# n_clusters:4, sil_score:0.28551734815532537, inertia:3153.4089543645373
# n_clusters:5, sil_score:0.3239420029825107, inertia:2572.9049472689712
# n_clusters:6, sil_score:0.322502414245171, inertia:2300.6318004591562
# n_clusters:7, sil_score:0.33363595775486876, inertia:2102.2151027786344
# n_clusters:8, sil_score:0.36777841789521715, inertia:1909.8927808165272
# n_clusters:9, sil_score:0.365486216099141, inertia:1769.285116612467
# n_clusters:10, sil_score:0.3642039547243806, inertia:1637.0747707143626
# n_clusters:11, sil_score:0.4395479868316505, inertia:1401.1701835583513
# n_clusters:12, sil_score:0.4510195441568725, inertia:1353.0254192003326
# n_clusters:13, sil_score:0.47663785272449827, inertia:1210.6195168999718
# n_clusters:14, sil_score:0.45124620743338745, inertia:1237.011691060601
# n_clusters:15, sil_score:0.4753110176843586, inertia:1097.8737700440313
# n_clusters:16, sil_score:0.4560273170776246, inertia:1083.6954534209192
# n_clusters:17, sil_score:0.5226883107130064, inertia:1079.6266104737917
# n_clusters:18, sil_score:0.47035631540537426, inertia:1013.4774521583956
# n_clusters:19, sil_score:0.5077468324809045, inertia:898.6325780050068
# n_clusters:20, sil_score:0.5321569739851949, inertia:889.7539078037493
# n_clusters:21, sil_score:0.5031390444643985, inertia:910.4341225412501
# n_clusters:22, sil_score:0.5542401406983387, inertia:834.0803734462884
# n_clusters:23, sil_score:0.5408242233265078, inertia:782.1514431887849
# n_clusters:24, sil_score:0.5575128981259039, inertia:781.4856373228944
# n_clusters:25, sil_score:0.5788251109420355, inertia:710.7966736951553
# n_clusters:26, sil_score:0.5867929259091543, inertia:723.6089845121476
# n_clusters:27, sil_score:0.5844117811146017, inertia:681.10182018613
# n_clusters:28, sil_score:0.5922766509606735, inertia:636.7719013820899
# n_clusters:29, sil_score:0.5833119536758633, inertia:637.559889236046
# n_clusters:30, sil_score:0.6106777060001126, inertia:593.0993257119509
# n_clusters:31, sil_score:0.6098764482257161, inertia:572.4228616918602
# n_clusters:32, sil_score:0.5969085770961848, inertia:598.9211459665111
# n_clusters:33, sil_score:0.6189339312182921, inertia:536.2151719986653
# n_clusters:34, sil_score:0.5979310161176031, inertia:585.1607263351747
# n_clusters:35, sil_score:0.6345896933249792, inertia:506.81358000379686
# n_clusters:36, sil_score:0.629359090871286, inertia:506.67920270614684
# n_clusters:37, sil_score:0.6562216522816852, inertia:498.90082951866304
# n_clusters:38, sil_score:0.6399212404617104, inertia:480.61979789930575
# n_clusters:39, sil_score:0.6681212984772001, inertia:468.41776890051614

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        17.868571  15.750739  248.085766    168
# 1        32.179670  12.937256  167.372603    878
#               mean        std         var  count
# cluster
# 0        41.333333  12.187425  148.533333     21
# 1        27.754982  11.622722  135.087668    568
# 2        31.997462  16.895149  285.446076    457
#               mean        std         var  count
# cluster
# 0        30.640180  11.619153  135.004719    667
# 1        39.133838  13.950457  194.615245    198
# 2        19.081608  15.955825  254.588364    143
# 3         8.986842   7.516187   56.493065     38
#               mean        std         var  count
# cluster
# 0        27.222612  11.487460  131.961731    490
# 1        37.807522  13.990930  195.746121    226
# 2        10.625000   8.897429   79.164244     44
# 3        33.559899  14.884394  221.545189    199
# 4        25.588161  16.347044  267.225852     87
#               mean        std         var  count
# cluster
# 0        35.433432  13.972446  195.229235    338
# 1        10.625000   8.897429   79.164244     44
# 2        23.478649  10.894436  118.688735     74
# 3        26.264213  11.183455  125.069655    375
# 4        26.014444  16.640749  276.914533     81
# 5        38.194030  13.754686  189.191393    134
#               mean        std         var  count
# cluster
# 0        25.990119  16.469457  271.243028     84
# 1        26.099705  11.227762  126.062643    407
# 2        36.868421  13.491623  182.023884    304
# 3        14.500000        NaN         NaN      1
# 4        22.498769  11.009159  121.201583     65
# 5        38.518519  13.194640  174.098535    135
# 6        11.300000   9.165708   84.010204     50
#               mean        std         var  count
# cluster
# 0        37.842657  13.199768  174.233872    143
# 1        36.230769  13.268084  176.042058    247
# 2        36.078431  12.240726  149.835372    102
# 3        10.848837   8.876490   78.792082     43
# 4        28.712418  10.369990  107.536698    306
# 5        12.039043  12.350498  152.534804     94
# 6        42.846154   9.281219   86.141026     13
# 7        23.204082   8.601677   73.988849     98
#               mean        std         var  count
# cluster
# 0        38.722222  12.982073  168.534222    126
# 1        29.581365  10.502628  110.305204    381
# 2        39.683246  13.301976  176.942560    191
# 3        28.359375  15.938508  254.036038     32
# 4        37.187500  10.759654  115.770161     32
# 5         8.986842   7.516187   56.493065     38
# 6         9.015195   9.167041   84.034636     77
# 7        24.660920   7.748028   60.031943     87
# 8        27.414634  12.368270  152.974104     82
#               mean        std         var  count
# cluster
# 0         8.490147   8.496550   72.191354     68
# 1        37.964567  13.263535  175.921354    127
# 2        36.188776  13.038507  170.002656     98
# 3        29.461756  10.939300  119.668278    353
# 4        42.846154   9.281219   86.141026     13
# 5        24.061395   8.555097   73.189689    129
# 6         8.893939   7.059742   49.839962     33
# 7        26.574915  14.428184  208.172505     59
# 8        38.125000  13.242795  175.371622    112
# 9        39.222222  14.082863  198.327044     54
#               mean        std         var  count
# cluster
# 0        27.705036   9.486512   89.993910    278
# 1        36.534884  12.313560  151.623754     43
# 2        38.113139  12.979338  168.463208    137
# 3        19.763889  10.495057  110.146230     36
# 4        35.419565  13.180849  173.734768    230
# 5        41.025974  13.589832  184.683527     77
# 6         8.893939   7.059742   49.839962     33
# 7         9.620130   8.920738   79.579572     77
# 8        24.743556  11.316443  128.061884     90
# 9        31.459459  10.457838  109.366366     37
# 10       39.875000   1.552648    2.410714      8
#               mean        std         var  count
# cluster
# 0        37.348837  13.150278  172.929822     86
# 1        28.701128  10.262864  105.326376    266
# 2        10.761905   8.965543   80.380952     42
# 3        12.284483  12.302683  151.356020     87
# 4        35.886792  13.286094  176.520299    212
# 5        24.072222   8.358055   69.857085     90
# 6        41.197368  13.596097  184.853860     76
# 7        42.846154   9.281219   86.141026     13
# 8        32.233333   8.884125   78.927684     60
# 9        14.500000        NaN         NaN      1
#               mean        std         var  count
# cluster
# 0        28.313253   9.654947   93.218009    249
# 1        32.551724  19.640676  385.756158     29
# 2        35.638889  11.272984  127.080159     36
# 3        14.500000        NaN         NaN      1
# 4        25.121053  10.166098  103.349552     95
# 5        28.500000  11.129317  123.861702     48
# 6        32.430328  12.325361  151.914527    122
# 7        45.195122  13.980736  195.460976     41
# 8         8.340517   8.493995   72.147956     58
# 9        32.833333  10.024396  100.488506     30
# 10       10.761905   8.965543   80.380952     42
# 11       39.875000   1.552648    2.410714      8
# 12       40.386364  13.430642  180.382135     44
# 13       16.860000  14.409967  207.647152     22
# 14       38.030612  13.223010  174.848002     49
# 15       42.404110  12.689852  161.032344     73
# 16       21.365385   7.088805   50.251154     26
# 17       34.219178  10.878427  118.340183     73
#               mean        std         var  count
# cluster
# 0        28.559908   9.845619   96.936209    217
# 1        26.134921  11.659555  135.945212     63
# 2         8.837838   7.562751   57.195195     37
# 3        33.758621   9.936963   98.743227     29
# 4        38.030612  13.223010  174.848002     49
# 5        24.164773   8.425032   70.981159     88
# 6        42.268657  13.584285  184.532791     67
# 7              NaN        NaN         NaN      0
# 8        29.669118  10.013279  100.265748     68
# 9        14.500000        NaN         NaN      1
# 10       15.710476   9.496202   90.177858     42
# 11       40.379121  13.222947  174.846337     91
# 12        4.484419   4.485524   20.119925     43
# 13       42.846154   9.281219   86.141026     13
# 14       33.032258   9.917943   98.365591     31
# 15       39.815789  13.249896  175.559744     38
# 16       32.250000  12.838069  164.816011     90
# 17       37.941176  16.974029  288.117647     34
# 18       31.955556  10.027135  100.543434     45

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.313253
# 1      40.893617
# 2      21.408774
# 3      38.125000
# 4      28.313253
#          ...
# 413    28.313253
# 414    40.893617
# 415    28.313253
# 416    28.313253
# 417     8.887885
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
known = age_df["Cabin_Title"] != "Unknown"

# %%
cluster_mode = age_df[known].groupby("cluster")["Cabin_Title"].agg(lambda s: s.mode()[0])

# %%
age_df["Has_Cabin"] = known.astype(int)
age_df["Deck_imputed"] = age_df["Cabin_Title"].where(known, age_df["cluster"].map(cluster_mode))
age_df["Deck_imputed"] = age_df["Deck_imputed"].fillna(age_df.loc[known, "Cabin_Title"].mode()[0])

# %%
age_df["Deck_imputed"]
# Out:
# 0      F
# 1      C
# 2      E
# 3      C
# 4      F
#       ..
# 413    F
# 414    C
# 415    F
# 416    F
# 417    C
# Name: Deck_imputed, Length: 1309, dtype: str

# %%
age_df.shape
# Out:
# (1309, 18)

# %%
age_df.Deck_imputed.value_counts()
# Out:
# Deck_imputed
# F    477
# C    463
# E    176
# B    119
# D     46
# A     22
# G      5
# T      1
# Name: count, dtype: int64
