# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("data/train.csv",encoding="utf-8")
test_df = pd.read_csv("data/test.csv",encoding="utf-8")

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_df.shape
# Out:
# (418, 11)

# %%
train_df["train_col"] = 1
test_df["train_col"] = 0

# %%
merged_df = pd.concat([train_df,test_df],axis=0)

# %%
merged_df.shape
# Out:
# (1309, 13)

# %%
merged_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# train_col         0
# dtype: int64

# %%
get_name = merged_df["Name"].apply(lambda x: x.split(",")[1])
get_title = get_name.apply(lambda x: x.split(".")[0])
merged_df["Title"] = get_title

# %%
title_map = {
    "Mr": "Mr",
    "Miss": "Miss",
    "Mlle": "Miss",
    "Ms": "Miss",
    "Mrs": "Mrs",
    "Mme": "Mrs",
    "Master": "Master",
    "Rev": "Rare",
    "Dr": "Rare",
    "Col": "Rare",
    "Major": "Rare",
    "Don": "Rare",
    "Dona": "Rare",
    "Lady": "Rare",
    "Sir": "Rare",
    "Capt": "Rare",
    "the Countess": "Rare",
    "Jonkheer": "Rare",
}

merged_df["Title"] = merged_df["Title"].str.strip().map(title_map)

# %%
merged_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  train_col   Title
# 0        0           A/5 21171    7.2500   NaN        S          1      Mr
# 1        0            PC 17599   71.2833   C85        C          1     Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S          1    Miss
# 3        0              113803   53.1000  C123        S          1     Mrs
# 4        0              373450    8.0500   NaN        S          1      Mr
# ..     ...                 ...       ...   ...      ...        ...     ...
# 413      0           A.5. 3236    8.0500   NaN        S          0      Mr
# 414      0            PC 17758  108.9000  C105        C          0    Rare
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          0      Mr
# 416      0              359309    8.0500   NaN        S          0      Mr
# 417      1                2668   22.3583   NaN        C          0  Master
#
# [1309 rows x 14 columns]

# %%
cabin_list = merged_df["Cabin"].astype(str).to_list()
cabin_list
cabins = []
for x in cabin_list:
    if str(x) == "nan":
        cabins.append("Unknown")
    else:
        cabins.append(x[0])

merged_df["Cabin_Title"] = cabins

# %%
merged_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df = merged_df.copy()

# %%
# age_df = age_df.drop(["Survived","Cabin"],axis=1)

# %%
age_df["Fare"] = age_df["Fare"].fillna(age_df["Fare"].median())
age_df["Embarked"] = age_df["Embarked"].fillna(age_df["Embarked"].mode()[0])

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# dtype: int64

# %%
age_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  train_col Title  \
# 0      0         A/5 21171   7.2500   NaN        S          1    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          1  Miss
# 3      0            113803  53.1000  C123        S          1   Mrs
# 4      0            373450   8.0500   NaN        S          1    Mr
#
#   Cabin_Title
# 0     Unknown
# 1           C
# 2     Unknown
# 3           C
# 4     Unknown

# %%
age_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'train_col', 'Title',
#        'Cabin_Title'],
#       dtype='str')

# %%
from sklearn.preprocessing import OrdinalEncoder

or_cols = ['Title','Embarked','Sex','Ticket']

scalers = {}
for col in or_cols:
    enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    age_df[col] = enc.fit_transform(age_df[[col]])

# %%
scale_cols = ["Fare", "SibSp", "Parch"]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
age_df[scale_cols] = scaler.fit_transform(age_df[scale_cols])

# %%
age_con = age_df["Age"].isna()

age_na = age_df[age_con]
age_not_na = age_df[~age_con]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

iners = []
sil_scores = []

features = ["Pclass","Sex","SibSp","Parch","Embarked","Title"]
data = age_df[features]

r = range(2,40)
for i in r:
    model = KMeans(n_clusters=i)
    model.fit(data)
    iner = model.inertia_
    sil_score = silhouette_score(data, model.predict(data))
    sil_scores.append(sil_score)
    iners.append(iner)
    print(f"n_clusters:{i}, sil_score:{sil_score}, inertia:{iner}")
# Out:
# n_clusters:2, sil_score:0.22170587459542, inertia:4660.341260065417
# n_clusters:3, sil_score:0.32499416532360775, inertia:3561.539274554507
# n_clusters:4, sil_score:0.34935157076655343, inertia:2963.47383879673
# n_clusters:5, sil_score:0.3270260241121059, inertia:2484.5476833409016
# n_clusters:6, sil_score:0.33780863459349975, inertia:2460.663227704401
# n_clusters:7, sil_score:0.30927181586711217, inertia:2233.632446031934
# n_clusters:8, sil_score:0.38963519659390283, inertia:1806.8437651597912
# n_clusters:9, sil_score:0.3940390703513524, inertia:1686.9450559728284
# n_clusters:10, sil_score:0.4069250586381396, inertia:1543.5669194532006
# n_clusters:11, sil_score:0.40491389900267005, inertia:1567.2823887246593
# n_clusters:12, sil_score:0.4485909502071903, inertia:1365.8255251567882
# n_clusters:13, sil_score:0.45525416858485057, inertia:1287.1103831863422
# n_clusters:14, sil_score:0.4536678493093543, inertia:1233.7058928029476
# n_clusters:15, sil_score:0.4679679447604963, inertia:1114.3918701598427
# n_clusters:16, sil_score:0.48216096621654064, inertia:1125.1361155655757
# n_clusters:17, sil_score:0.4870660321808731, inertia:1026.5911409821251
# n_clusters:18, sil_score:0.47648410239193595, inertia:1017.174058081006
# n_clusters:19, sil_score:0.5145206732438629, inertia:903.1276019714767
# n_clusters:20, sil_score:0.5126268759193617, inertia:905.5094804812708
# n_clusters:21, sil_score:0.556164173493292, inertia:840.5645177140559
# n_clusters:22, sil_score:0.5524210829124623, inertia:811.2814531536982
# n_clusters:23, sil_score:0.5738029303824281, inertia:790.4333353694885
# n_clusters:24, sil_score:0.5404377663042526, inertia:808.020073254991
# n_clusters:25, sil_score:0.584766941319878, inertia:729.988501162183
# n_clusters:26, sil_score:0.5539723467835244, inertia:718.0985453570192
# n_clusters:27, sil_score:0.5935279872159162, inertia:662.5788662600016
# n_clusters:28, sil_score:0.5857352307611189, inertia:650.0535460470524
# n_clusters:29, sil_score:0.602004250919445, inertia:634.1253498132689
# n_clusters:30, sil_score:0.5977941241732475, inertia:596.9216809713089
# n_clusters:31, sil_score:0.6254802589535926, inertia:626.3170015961464
# n_clusters:32, sil_score:0.6223652497783052, inertia:556.064832251659
# n_clusters:33, sil_score:0.6147297566999264, inertia:619.5354805206321
# n_clusters:34, sil_score:0.5981727248473148, inertia:568.0955927743171
# n_clusters:35, sil_score:0.6477243994067572, inertia:507.84364223118115
# n_clusters:36, sil_score:0.6566465713749697, inertia:493.9939440705126
# n_clusters:37, sil_score:0.6410584865697486, inertia:491.9454986290898
# n_clusters:38, sil_score:0.6654561094912589, inertia:499.64459406157357
# n_clusters:39, sil_score:0.6411652119424783, inertia:495.0476455805117

# %%
import matplotlib.pyplot as plt

k_range = r

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(k_range, iners, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow Method")

axes[1].plot(k_range, sil_scores, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette Score")
axes[1].set_title("Silhouette Score by k")

plt.tight_layout()
plt.show()

# %%
for x in range(1,20):
    k_best = KMeans(n_clusters=x)
    clusters = k_best.fit_predict(age_df[features])
    age_df["cluster"] = clusters

    age_stats = age_df.groupby("cluster")["Age"].agg(["mean", "std", "var", "count"])
    print(age_stats)
# Out:
#               mean        std         var  count
# cluster
# 0        29.881138  14.413493  207.748787   1046
#               mean        std         var  count
# cluster
# 0        32.208007  12.902509  166.474751    893
# 1        16.300131  15.292568  233.862650    153
#               mean        std         var  count
# cluster
# 0        28.287300  10.887458  118.536734    563
# 1        38.643917  13.322384  177.485923    337
# 2        15.800822  15.445591  238.566294    146
#               mean        std         var  count
# cluster
# 0        20.562977  16.947235  287.208763    131
# 1        10.848837   8.876490   78.792082     43
# 2        32.552385  14.367647  206.429277    218
# 3        32.108563  12.369087  152.994322    654
#               mean        std         var  count
# cluster
# 0        25.588161  16.347044  267.225852     87
# 1        27.062788  11.571956  133.910157    495
# 2        10.625000   8.897429   79.164244     44
# 3        33.559899  14.884394  221.545189    199
# 4        38.404977  13.499832  182.245475    221
#               mean        std         var  count
# cluster
# 0        20.798780  11.884038  141.230370    164
# 1        29.458449  10.717441  114.863546    361
# 2        10.625000   8.897429   79.164244     44
# 3        38.300725  13.118291  172.089562    138
# 4        25.588161  16.347044  267.225852     87
# 5        36.630952  14.112409  199.160074    252
#               mean        std         var  count
# cluster
# 0        35.278409  13.056987  170.484903    176
# 1        19.897516  11.943683  142.651560    161
# 2        37.684564  12.940136  167.447125    149
# 3        31.455294  12.084866  146.043987    425
# 4        26.541236  16.924333  286.433047     89
# 5        10.733333   8.917297   79.518182     45
# 6        14.500000        NaN         NaN      1
#               mean        std         var  count
# cluster
# 0        38.008929  13.024921  169.648568    112
# 1        27.654237   9.596490   92.092627    295
# 2        10.848837   8.876490   78.792082     43
# 3        24.035625  11.789054  138.981785     96
# 4        35.146288  13.136572  172.569515    229
# 5        37.250000  11.199244  125.423077     40
# 6        38.300725  13.118291  172.089562    138
# 7        13.362903  12.966894  168.140334     93
#               mean        std         var  count
# cluster
# 0        39.811321  13.962941  194.963716     53
# 1        36.425234  13.340810  177.977205    321
# 2        37.868421  11.121372  123.684922     38
# 3        24.409213  11.685018  136.539635     89
# 4        14.500000        NaN         NaN      1
# 5        10.761905   8.965543   80.380952     42
# 6        36.500000  12.735081  162.182292     97
# 7        11.508523  11.147085  124.257498     88
# 8        27.829653   9.546572   91.137029    317
#               mean        std         var  count
# cluster
# 0        10.098101   8.966747   80.402544     79
# 1        28.462151   9.863649   97.291562    251
# 2         9.551282   8.211669   67.431511     39
# 3        39.875000   1.552648    2.410714      8
# 4        38.771654  13.163766  173.284746    127
# 5        24.657882  12.316922  151.706579     85
# 6        24.072222   8.358055   69.857085     90
# 7        36.534884  12.313560  151.623754     43
# 8        38.008929  13.024921  169.648568    112
# 9        35.886792  13.286094  176.520299    212
#               mean        std         var  count
# cluster
# 0        21.355505   9.918051   98.367727    109
# 1        28.526531   9.884492   97.703187    245
# 2        41.277778  10.565235  111.624183     18
# 3        39.450980  14.041814  197.172549     51
# 4        14.500000        NaN         NaN      1
# 5        35.859223  13.282928  176.436183    206
# 6        10.761905   8.965543   80.380952     42
# 7        36.188776  13.038507  170.002656     98
# 8        17.690841  14.935908  223.081347    107
# 9        37.789474  13.007468  169.194224    114
# 10       28.781818  11.245478  126.460774     55
#               mean        std         var  count
# cluster
# 0        36.829268  16.921735  286.345122     41
# 1        35.916667  13.171862  173.497947    204
# 2        10.369048   8.400827   70.573897     42
# 3        34.208696  13.816622  190.899047    115
# 9        14.458333   9.532458   90.867754     24
# 10       14.870000  12.427378  154.439720     41
# 11       33.032258   9.917943   98.365591     31
# 12       40.379121  13.222947  174.846337     91
# 13       14.500000        NaN         NaN      1
# 14       27.812500   8.612128   74.168750     56
# 15       39.456897  13.806077  190.607759     58
# 16       32.884615   9.155313   83.819759     52
#               mean        std         var  count
# cluster
# 0        27.566667  12.347507  152.460920     30
# 1        29.254902  11.231372  126.143725     51
# 2        10.761905   8.965543   80.380952     42
# 3        40.826087  13.594614  184.813527     46
# 4        32.508264  12.346387  152.433264    121
# 5         9.537500  10.587468  112.094480     60
# 6        28.313253   9.654947   93.218009    249
# 7        37.061111  12.531046  157.027122     90
# 8        39.592105  11.925362  142.214260     38
# 9              NaN        NaN         NaN      0
# 10       21.203704   7.001730   49.024217     27
# 11       30.823529   9.916227   98.331551     34
# 12       14.500000        NaN         NaN      1
# 13       24.235714   8.815632   77.715373     70
# 14       39.947368  11.792058  139.052632     19
# 15       16.352258  15.533850  241.300491     31
# 16       42.404110  12.689852  161.032344     73
# 17       39.343750  13.465086  181.308532     64
#               mean        std         var  count
# cluster
# 0        14.500000        NaN         NaN      1
# 1        28.827586  10.301327  106.117331    232
# 2        40.391304  13.149530  172.910145     46
# 3        35.129630  13.326948  177.607550     27
# 4        33.000000  18.627936  347.000000     15
# 5        37.919355  10.700543  114.501613     31
# 6         4.506400   4.054793   16.441349     25
# 7        35.521053  13.101540  171.650348    190
# 8        34.126437  13.051378  170.338479     87
# 9        23.812500   9.048943   81.883363     72
# 10       42.571429  13.763807  189.442396     63
# 11       41.500000   2.121320    4.500000      2
# 12       32.395833  10.182880  103.691046     48
# 13       26.654762   7.819993   61.152294     42
# 14       22.391304   6.885354   47.408103     23
# 15        8.837838   7.562751   57.195195     37
# 16       12.897105  10.151731  103.057648     38
# 17       10.337273   8.551382   73.126135     22
# 18       34.044444  12.799069  163.816162     45

# %%
k_best = KMeans(n_clusters=11)
clusters = k_best.fit_predict(age_df[features])
age_df["cluster"] = clusters

# %%
cluster_means = age_df.groupby("cluster")["Age"].transform("mean")
age_df["Age"] = age_df["Age"].fillna(cluster_means)

# %%
cluster_means
# Out:
# 0      28.562500
# 1      38.438462
# 2      24.072222
# 3      38.166667
# 4      28.562500
#          ...
# 413    28.562500
# 414    38.438462
# 415    28.562500
# 416    28.562500
# 417    22.350313
# Name: Age, Length: 1309, dtype: float64

# %%
age_df["Age"].isna().sum()
# Out:
# np.int64(0)

# %%
age_df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
age_df.shape
# Out:
# (1309, 16)

# %%
age_df.Cabin.isna().sum()
# Out:
# np.int64(1014)

# %%
cabin_con = age_df.Cabin.isna()
cabin_na_df = age_df[cabin_con]
cabin_df = age_df[~cabin_con]

# %%
cabin_na_df.isna().sum()
# Out:
# PassengerId       0
# Survived        327
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# train_col         0
# Title             0
# Cabin_Title       0
# cluster           0
# dtype: int64

# %%
cabin_df.isna().sum()
# Out:
# PassengerId     0
# Survived       91
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        0
# train_col       0
# Title           0
# Cabin_Title     0
# cluster         0
# dtype: int64

# %%
cabin_df.Cabin.value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F2                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64
